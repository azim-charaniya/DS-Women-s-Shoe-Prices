# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

import re
import os
# %matplotlib inline

# %%
df = pd.read_csv("Datafiniti_Womens_Shoes.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  object
#  1   dateAdded            10000 non-null  object
#  2   dateUpdated          10000 non-null  object
#  3   asins                3 non-null      object
#  4   brand                10000 non-null  object
#  5   categories           10000 non-null  object
#  6   primaryCategories    10000 non-null  object
#  7   colors               2631 non-null   object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            10000 non-null  object
#  11  keys                 10000 non-null  object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 10000 non-null  object
#  15  prices.amountMax     10000 non-null  float64
#  16  prices.amountMin     10000 non-null  float64
#  17  prices.availability  434 non-null    object
#  18  prices.color         10000 non-null  object
#  19  prices.condition     438 non-null    object
#  20  prices.currency      10000 non-null  object
#  21  prices.dateAdded     9223 non-null   object
#  22  prices.dateSeen      10000 non-null  object
#  23  prices.isSale        10000 non-null  bool
#  24  prices.merchant      435 non-null    object
#  25  prices.offer         121 non-null    object
#  26  prices.returnPolicy  0 non-null      float64
#  27  prices.shipping      412 non-null    object
#  28  prices.size          10000 non-null  object
#  29  prices.sourceURLs    10000 non-null  object
#  30  sizes                10000 non-null  object
#  31  sourceURLs           10000 non-null  object
#  32  upc                  9640 non-null   object
#  33  weight               299 non-null    object
# dtypes: bool(1), float64(4), object(29)
# memory usage: 2.5+ MB

# %%
df.head().T
# Out:
#                                                                      0  \
# id                                                AVpfEf_hLJeJML431ueH
# dateAdded                                         2015-05-04T12:13:08Z
# dateUpdated                                       2018-01-29T04:38:43Z
# asins                                                              NaN
# brand                                                      Naturalizer
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                                Shoes
# colors                                  Silver,Cream Watercolor Floral
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://i5.walmartimages.com/asr/861ca6cf-fa55...
# keys                 naturalizer/47147sc022,017136472311,womensnatu...
# manufacturer                                                       NaN
# manufacturerNumber                                          47147SC022
# name                 Naturalizer Danya Women N/S Open Toe Synthetic...
# prices.amountMax                                                 55.99
# prices.amountMin                                                 55.99
# prices.availability                                                NaN
# prices.color                                        UWomens  M Regular
# prices.condition                                                   NaN
# prices.currency                                                    USD
# prices.dateAdded                                  2017-03-28T11:40:25Z
# prices.dateSeen      2017-03-25T09:19:24.819Z,2017-03-25T09:19:19.600Z
# prices.isSale                                                    False
# prices.merchant                                          Overstock.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                    NaN
# prices.size                                                          S
# prices.sourceURLs    https://www.overstock.com/Clothing-Shoes/Women...
# sizes                6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# sourceURLs           https://www.walmart.com/ip/Naturalizer-Danya-W...
# upc                                                       017136472311
# weight                                                             NaN
#
#                                                                      1  \
# id                                                AVpi74XfLJeJML43qZAc
# dateAdded                                         2017-01-27T01:23:39Z
# dateUpdated                                       2018-01-03T05:21:54Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                                          NaN
# ean                                                      33977045743.0
# imageURLs            https://i5.walmartimages.com/asr/421de5d5-3a74...
# keys                 mukluks/00173650206,033977045743,muklukswomens...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017365020-6
# name                               MUK LUKS Womens Jane Suede Moccasin
# prices.amountMax                                                  47.0
# prices.amountMin                                                 35.25
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2018-01-03T05:21:54Z
# prices.dateSeen      2017-12-08T14:24:00.000Z,2017-11-01T02:52:00.000Z
# prices.isSale                                                     True
# prices.merchant                                            Walmart.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                               Standard
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# upc                                                       033977045743
# weight                                                             NaN
#
#                                                                      2  \
# id                                                AVpi74XfLJeJML43qZAc
# dateAdded                                         2017-01-27T01:23:39Z
# dateUpdated                                       2018-01-03T05:21:54Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                                          NaN
# ean                                                      33977045743.0
# imageURLs            https://i5.walmartimages.com/asr/421de5d5-3a74...
# keys                 mukluks/00173650206,033977045743,muklukswomens...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017365020-6
# name                               MUK LUKS Womens Jane Suede Moccasin
# prices.amountMax                                                 35.25
# prices.amountMin                                                 35.25
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2017-12-06T05:02:42Z
# prices.dateSeen      2017-11-10T15:11:00.000Z,2017-11-18T08:00:00.000Z
# prices.isSale                                                    False
# prices.merchant                                       Slippers Dot Com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                  Value
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# upc                                                       033977045743
# weight                                                             NaN
#
#                                                                      3  \
# id                                                AVpjXyCc1cnluZ0-V-Gj
# dateAdded                                         2017-01-27T01:25:56Z
# dateUpdated                                       2018-01-04T11:52:35Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                          Shoes,Shoes
# colors                                                           Black
# dimension                                     6.0 in x 6.0 in x 1.0 in
# ean                                                      33977045903.0
# imageURLs            https://i5.walmartimages.com/asr/950d38a5-0113...
# keys                 033977045903,muklukswomensdawnsuedescuffslippe...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017366001-6
# name                          MUK LUKS Womens Dawn Suede Scuff Slipper
# prices.amountMax                                                 24.75
# prices.amountMin                                                 24.75
# prices.availability                                           In Stock
# prices.color                                                     Black
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2018-01-04T11:52:35Z
# prices.dateSeen                               2017-12-07T16:37:00.000Z
# prices.isSale                                                    False
# prices.merchant                                       Slippers Dot Com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                  Value
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# upc                                                       033977045903
# weight                                                             NaN
#
#                                                                      4
# id                                                AVphGKLPilAPnD_x1Nrm
# dateAdded                                         2017-01-27T01:25:56Z
# dateUpdated                                       2018-01-18T03:55:18Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                     6.0 in x 6.0 in x 1.0 in
# ean                                                      33977045958.0
# imageURLs            https://i5.walmartimages.com/asr/5e137bc3-c900...
# keys                 mukluks/00173660206,033977045958,0033977045958...
# manufacturer                                                       NaN
# manufacturerNumber                                        0017366020-6
# name                          MUK LUKS Womens Dawn Suede Scuff Slipper
# prices.amountMax                                                  33.0
# prices.amountMin                                                 30.39
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2017-12-04T21:35:47Z
# prices.dateSeen                               2017-11-17T21:15:00.000Z
# prices.isSale                                                     True
# prices.merchant                                            Walmart.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                              Expedited
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# upc                                                       033977045958
# weight                                                             NaN

# %%
df.colors.fillna(df["prices.color"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  object
#  1   dateAdded            10000 non-null  object
#  2   dateUpdated          10000 non-null  object
#  3   asins                3 non-null      object
#  4   brand                10000 non-null  object
#  5   categories           10000 non-null  object
#  6   primaryCategories    10000 non-null  object
#  7   colors               10000 non-null  object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            10000 non-null  object
#  11  keys                 10000 non-null  object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 10000 non-null  object
#  15  prices.amountMax     10000 non-null  float64
#  16  prices.amountMin     10000 non-null  float64
#  17  prices.availability  434 non-null    object
#  18  prices.color         10000 non-null  object
#  19  prices.condition     438 non-null    object
#  20  prices.currency      10000 non-null  object
#  21  prices.dateAdded     9223 non-null   object
#  22  prices.dateSeen      10000 non-null  object
#  23  prices.isSale        10000 non-null  bool
#  24  prices.merchant      435 non-null    object
#  25  prices.offer         121 non-null    object
#  26  prices.returnPolicy  0 non-null      float64
#  27  prices.shipping      412 non-null    object
#  28  prices.size          10000 non-null  object
#  29  prices.sourceURLs    10000 non-null  object
#  30  sizes                10000 non-null  object
#  31  sourceURLs           10000 non-null  object
#  32  upc                  9640 non-null   object
#  33  weight               299 non-null    object
# dtypes: bool(1), float64(4), object(29)
# memory usage: 2.5+ MB

# %%
#df["colors"] = df['colors'].str.split(',')
#df = df.explode('colors').reset_index(drop=True)

# %%
df["color"] = df["prices.color"].str.lower()

# %%
df[df['color'].str.contains("gold", na=False)]["color"].unique()
# Out:
# array(['black rose gold', 'black gold', 'rose gold', 'gold', 'rosegold',
#        'soft gold', 'gold snake', 'rose gold glitter', 'rose gold brown',
#        'washed gold', 'metal gold', 'black gold combo', 'gold metallic',
#        'brindle/inca gold'], dtype=object)

# %%
df.color.value_counts().head(50)
# Out:
# black           1962
# gray             737
# taupe            558
# navy             535
# brown            301
# nude             225
# white            221
# blue             177
# stone            168
# tan              167
# pewter           157
# red              145
# black white      126
# chestnut         109
# mushroom         104
# olive             96
# dark tan          95
# silver            89
# gold              76
# cognac            72
# wine              72
# black fabric      69
# pink              69
# natural           65
# black micro       63
# slate             63
# blush             61
# dark gray         61
# sand              55
# black patent      53
# whiskey           53
# dark brown        51
# stucco            49
# bone              49
# black gray        49
# burgundy          49
# white black       47
# white sand        47
# lux navy          43
# camel             41
# navy fabric       40
# black combo       39
# black snake       37
# dark red          35
# gray pink         34
# navy velvet       33
# charcoal          31
# denim             31
# gray black        30
# chocolate         30
# Name: color, dtype: int64

# %%
df.color.value_counts()
# Out:
# black                1962
# gray                  737
# taupe                 558
# navy                  535
# brown                 301
#                      ...
# dark green nubuck       1
# wood                    1
# orange                  1
# brown tweed             1
# gray blue pink          1
# Name: color, Length: 544, dtype: int64

# %%
# Spell Check for Gray
df["color"].replace(df[df['color'].str.contains("grey",na=False)]["color"].unique(), "gray", inplace=True)

# %%
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)

# %%
df.color.value_counts().head(50)
# Out:
# black                  2829
# gray                   1070
# navy                    741
# taupe                   573
# white                   430
# brown                   332
# nude                    231
# blue                    221
# stone                   185
# tan                     174
# pewter                  166
# red                     164
# silver                  128
# pink                    109
# chestnut                109
# mushroom                104
# olive                    96
# dark tan                 95
# wine                     89
# cognac                   84
# gold                     83
# natural                  70
# blush                    68
# slate                    66
# dark gray                61
# stucco                   57
# sand                     55
# burgundy                 54
# whiskey                  53
# dark brown               51
# charcoal                 50
# bone                     49
# lux navy                 43
# camel                    41
# dark red                 35
# denim                    31
# chocolate                31
# chambray blue combo      27
# raspberry                27
# purple                   26
# dark navy                24
# army                     24
# bronze                   23
# inky navy                23
# soft gold                23
# rosegold                 22
# rose gold                21
# midnight                 21
# beige                    19
# green                    18
# Name: color, dtype: int64

# %%
for n in df.color.value_counts().head(12).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)
for n in df.color.value_counts().head(12).index:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black            2888
# gray             1179
# navy              850
# taupe             577
# white             451
# brown             414
# blue              322
# tan               279
# nude              231
# red               213
# stone             189
# pewter            166
# silver            128
# pink              109
# chestnut          109
# mushroom          104
# olive              96
# wine               89
# cognac             84
# gold               83
# natural            70
# blush              68
# slate              66
# stucco             57
# sand               55
# burgundy           54
# whiskey            53
# charcoal           50
# bone               49
# camel              41
# denim              31
# chocolate          31
# raspberry          27
# purple             26
# army               24
# soft gold          23
# bronze             23
# rosegold           22
# midnight           21
# rose gold          21
# beige              19
# green              18
# merlot velvet      17
# metallic           17
# turquoise          16
# snake              15
# ice                14
# plum               14
# coral              13
# mauve              13
# Name: color, dtype: int64

# %%
commonCenterColors = ["navy","pink","gold","green","silver","chocolate","velvet","pewter","purple","bronze","nude","bone","rose","wine"]

# %%
for n in commonCenterColors:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)

for n in commonCenterColors:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black        2888
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# slate          66
# rose           66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# chocolate      32
# velvet         31
# denim          31
# purple         30
# raspberry      27
# army           24
# bronze         23
# midnight       21
# beige          19
# metallic       17
# turquoise      16
# snake          15
# plum           14
# ice            14
# coral          13
# mauve          13
# tornado        12
# leopard        11
# Name: color, dtype: int64

# %%
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black        2888
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# slate          66
# rose           66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# coral          32
# chocolate      32
# denim          31
# velvet         31
# purple         30
# beige          28
# raspberry      27
# metallic       24
# army           24
# bronze         23
# leopard        22
# midnight       21
# snake          20
# ice            16
# turquoise      16
# plum           14
# mauve          14
# tornado        12
# Name: color, dtype: int64

# %%
df.color.value_counts()
# Out:
# black                          2888
# gray                           1179
# navy                            850
# taupe                           577
# white                           451
#                                ...
# stripe                            1
# oro legacy leather                1
# animal                            1
# mahogany oro-iginal leather       1
# orange                            1
# Name: color, Length: 135, dtype: int64

# %%
df.color.value_counts().head(50)
# Out:
# black        2888
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# slate          66
# rose           66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# chocolate      32
# velvet         31
# denim          31
# purple         30
# raspberry      27
# army           24
# bronze         23
# midnight       21
# beige          19
# metallic       17
# turquoise      16
# snake          15
# plum           14
# ice            14
# coral          13
# mauve          13
# tornado        12
# leopard        11
# Name: color, dtype: int64

# %%
df.color.value_counts().tail(50)
# Out:
# mocha                                    3
# maroon                                   2
# brunette                                 2
# almond                                   2
# bordeaux                                 2
# indigo burst                             2
# quilt metallic                           2
# wheat nubuck                             2
# basalt/tapa                              2
# unc multi                                2
# bleach                                   2
# morning dove heritage canvas             2
# aqua                                     2
# fatigue                                  2
# tobacco oiled leather                    1
# beige metallic                           1
# willow                                   1
# team colors                              1
# night maroon                             1
# mint                                     1
# gunmetal                                 1
# fusion coral                             1
# poseidon/vintage indigo                  1
# animal                                   1
# multi unicorn                            1
# medium beige                             1
# capri/poseidon                           1
# ram team                                 1
# honey                                    1
# uwomens  n narrow                        1
# buckskin                                 1
# stripe                                   1
# mahogany oro-iginal leather              1
# floral combo                             1
# koa/tapa                                 1
# aquarium coral                           1
# dusted peach                             1
# fjord                                    1
# sunrise                                  1
# shell                                    1
# camouflage                               1
# hawaiian surf/astral aura/grape juice    1
# uwomens  m regular                       1
# twilight/mauveine                        1
# orange                                   1
# birch                                    1
# habana oiled leather                     1
# wild rice                                1
# oro legacy leather                       1
# wood                                     1
# Name: color, dtype: int64

# %%
import seaborn as sns

colors = df.color.value_counts().head(5).index
for n in colors:
    sns.histplot(df[(df["prices.amountMax"] < 350) & (df.color == n)]["prices.amountMax"],bins=30,kde=False,common_bins=True,label=n)

plt.suptitle('Shoes Price Distribution for top 5 colors', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")

plt.legend()

# %%
colors =df.color.value_counts().head(10).index
for n in colors:
    sns.kdeplot(df[(df["prices.amountMax"] < 350) & (df.color == n)]["prices.amountMax"], legend=True,label=n)

plt.suptitle('Shoes Price Distribution for top 10 colors', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")
plt.legend()

# %%
data = df.color.value_counts().head(10)

sns.barplot(x=data.index, y=data.values, palette=["black","gray","navy","#BAA68E","green","brown","blue","tan","#BC9E82","red"])
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize = (12, 8))

sns.histplot(x = df['prices.amountMax'], kde=True, bins=50)
plt.suptitle('Shoes Price Distribution', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (12, 8))

sns.histplot(x = df[(df["prices.amountMax"] < 250)]["prices.amountMax"], kde=True, bins=50)
plt.suptitle('Shoes Price Distribution Price Less than 250', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")

plt.show()

# %%
fig, ax = plt.subplots(2,1,figsize = (12, 8))

sns.boxplot(x = df["prices.amountMax"], ax = ax[0])
sns.histplot(x = df["prices.amountMax"], ax = ax[1], bins=30)
plt.suptitle('Box Plot for Prices', fontsize = 20)
plt.xlabel("Price Range")

plt.show()

# %%
top_brands =df.groupby('brand')['name'].count().reset_index().sort_values('name',ascending=False).head(10).set_index('brand')
plt.subplots(figsize=(14,7))
ax = top_brands['name'].sort_values().plot.barh(width=0.9,color=sns.color_palette('CMRmap',12))
ax.set_xlabel("Total items", fontsize=18)
ax.set_ylabel("Brand", fontsize=18)
ax.set_title("Top 10 Brands",fontsize=18,color='black')
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+2, i.get_y()+.3,str(round(i.get_width())), fontsize=15,color='black')
plt.show()

# %%
df =df.sort_values('prices.amountMax',ascending=False)
costliest_products =df.groupby('color')['prices.amountMax'].first().reset_index().sort_values('prices.amountMax',ascending=False).head(10).set_index('color')
plt.subplots(figsize=(14,7))
ax = costliest_products['prices.amountMax'].sort_values().plot.barh(width=0.9,color=sns.color_palette('gnuplot2_r',10))
ax.set_xlabel("Cost", fontsize=18)
ax.set_ylabel("color", fontsize=18)
ax.set_title("Costliest products of top 10 color",fontsize=18,color='black')
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+2, i.get_y()+.3,str(round(i.get_width())), fontsize=15,color='black')
plt.show()

# %%
def getValidColor(c):
    _map = {'taupe': "#b38b6d","brown":"#A52A2A","nude":"green"}
    if c in _map.keys() :
        return _map[c]
    else:
        return c

# %%
import seaborn as sns
import math

fig, ax = plt.subplots(3, 3,figsize=(12,12))



colors = df.color.value_counts().head(9).index
for idx, n in enumerate(colors):
    _ax = ax[math.floor(idx/3)][idx%3]
    sns.histplot(df[(df["prices.amountMax"] < 350) & (df.color == n)]["prices.amountMax"],bins=30,kde=True,common_bins=True,label=n, ax = _ax, color=getValidColor(n))
    _ax.set_xlabel("Price Range")
    _ax.set_ylabel("Frequency")
    _ax.legend()
    _ax.lines[0].set_color('crimson')
    

plt.suptitle('Shoes Price Distribution for top 4 colors', fontsize = 20)


plt.legend()

# %%
import seaborn as sns
import math

fig, ax = plt.subplots(3, 3,figsize=(12,12))



colors = df.color.value_counts().head(9).index
for idx, n in enumerate(colors):
    _ax = ax[math.floor(idx/3)][idx%3]
    data = df[df.color=="black"]["brand"].value_counts().head(10)
    sns.barplot(x=data.values, y=data.index, ax = _ax, color=getValidColor(n),orient='h')
    _ax.set_xlabel("Price Range for "+n)
    #_ax.set_ylabel("Frequency")
    #_ax.legend()
    

plt.suptitle('Brand Price Distribution for top 9 colors', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Brand Price Distribution for top 9 colors')

# %%
data = df[df.color=="black"]["brand"].value_counts().head(10)

# %%
df["name"].value_counts()
# Out:
# Nike Flex Experience 6 Women's Running Shoes                185
# LifeStride Lively Women's High Heels                        157
# Dr. Scholl's Madison Women's Sneakers                       144
# Simply Vera Vera Wang Women's All-Over Stretch Heels        121
# Dr. Scholl's Jorie Women's Ankle Boots                      109
#                                                            ...
# Brinley Co. Women's Cammie Buckle Detail Wide Calf Boots      1
# Betula by Birkenstock Mia Women's Footbed Sandals             1
# Asics GEL-FujiEndurance Trail Running Shoe - Women's          1
# Mo Mo Women's Outlander Heeled Hiker Boot                     1
# Ryka Grafik 2 Women's Cross Training Shoes                    1
# Name: name, Length: 649, dtype: int64

# %%
from collections import Counter
Counter(" ".join(df["name"].str.lower()).split()).most_common(100)
# Out:
# [("women's", 9878),
#  ('collection', 2183),
#  ('journee', 2182),
#  ('boots', 2067),
#  ('sandals', 1810),
#  ('ankle', 1794),
#  ('lifestride', 1593),
#  ('heels', 1507),
#  ('high', 1420),
#  ('by', 1393),
#  ('shoes', 1356),
#  ('flats', 987),
#  ('charles', 956),
#  ('running', 813),
#  ('wedge', 715),
#  ('a2', 670),
#  ('aerosoles', 670),
#  ('-', 638),
#  ('easy', 608),
#  ('street', 596),
#  ('shoe', 580),
#  ('heel', 559),
#  ('style', 520),
#  ('david', 478),
#  ('nike', 464),
#  ('so', 422),
#  ('dress', 419),
#  ('ballet', 405),
#  ('loafers', 382),
#  ('vera', 343),
#  ('dr.', 338),
#  ("scholl's", 338),
#  ('wedges', 336),
#  ('sneakers', 331),
#  ('block', 320),
#  ('skechers', 320),
#  ('croft', 315),
#  ('barrow', 315),
#  ('ortholite', 275),
#  ('flex', 272),
#  ('new', 269),
#  ('balance', 267),
#  ('for', 240),
#  ('sonoma', 229),
#  ('goods', 229),
#  ('life', 229),
#  ('6', 219),
#  ('clogs', 218),
#  ('toe', 212),
#  ('2', 193),
#  ('training', 188),
#  ('9', 187),
#  ('experience', 185),
#  ('apt.', 183),
#  ('trail', 181),
#  ('simply', 164),
#  ('wang', 164),
#  ('peep', 158),
#  ('lively', 157),
#  ('dakota', 152),
#  ('pointed', 150),
#  ('ryka', 147),
#  ('mary', 146),
#  ('stretch', 145),
#  ('madison', 144),
#  ("candie's", 144),
#  ('jane', 143),
#  ('velocity', 136),
#  ('ankle-high', 136),
#  ('4', 134),
#  ('faux', 132),
#  ('asics', 130),
#  ('leather', 127),
#  ("d'orsay", 126),
#  ('v2', 122),
#  ('all-over', 121),
#  ('air', 117),
#  ('jorie', 109),
#  ('backless', 109),
#  ('step', 108),
#  ('naturalizer', 108),
#  ('naturalsoul', 107),
#  ('white', 105),
#  ('dig', 104),
#  ('diverse', 104),
#  ('adidas', 100),
#  ('too', 99),
#  ('block-heel', 97),
#  ('espadrille', 96),
#  ('foam', 96),
#  ('oxford', 96),
#  ('lynne', 93),
#  ('raelin', 93),
#  ('sandal', 93),
#  ('leona', 92),
#  ('chlear', 92),
#  ('sailing', 92),
#  ('slip-on', 91),
#  ('v3', 90),
#  ('cross', 89)]

# %%
commonKeyWords = ['women','sandal','heel','high','boots','shoe']

# %%
for n in commonKeyWords:
    df[n] = df["name"].apply(lambda x: n in x.lower())

# %%
df["shoe"].value_counts()
# Out:
# False    8089
# True     1911
# Name: shoe, dtype: int64

# %%
df[commonKeyWords].apply(pd.value_counts).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['prices.size'].isnull().sum()
# Out:
# 0

# %%
df['prices.size'].unique()
# Out:
# array(['7.5', '7', '9.5', '10', '6.5', '11', '6', '8', '9', '8.5', '39',
#        '37', 'US 9.5/UK 8.0', 'US 9.0/UK 7.5', 'US 8.5/UK 7.0', '38.5',
#        '39.5', '42', '36', '40.5', '10.5', 'US 7.5/UK 6.0',
#        'US 6.5/UK 5.0', 'S', 'US 10.0/UK 8.5', 'US 8.0/UK 6.5',
#        'US 10.5/UK 9.0', '40', '41', '11 MED', '7 MED', '9 WIDE',
#        '7.5 WIDE', '9.5 MED', '41.5', 'US 11.0/UK 9.5', 'US 6.0/UK 4.5',
#        'US 7.0/UK 5.5', '40 WIDE', '6 MED', '9 MED', '8.5 MED', '6.5 MED',
#        '8 MED', '10 MED', '5', '36 WIDE', '38 WIDE', '41 WIDE', '7.5 MED',
#        '5 MED', '8 WIDE', '6 WIDE', '7 WIDE', '11 WIDE', '8.5 WIDE',
#        '9.5 WIDE', '12', '12 MED', '5.5 MED', '10.5 MED', '10 WIDE',
#        '6.5 WIDE', '5.5', '35', '12 WIDE', '10.5 WIDE', '38',
#        'Mens 5.5/Womens 7.0', '11.5', '11.5 WIDE', '5 WIDE', '5.5 WIDE',
#        'Mens 6.0/Womens 7.5', 'Mens 7.5/Womens 9.0',
#        'Mens 8.5/Womens 10.0', 'Mens 7.0/Womens 8.5',
#        'Mens 4.5/Womens 6.0', 'Medium', '4', 'MEDIUM', 'SMALL', 'LARGE'],
#       dtype=object)

# %%
#check unique data 
df['prices.size'] = df['prices.size'].str.lower()
df['prices.size'].unique()
# Out:
# array(['7.5', '7', '9.5', '10', '6.5', '11', '6', '8', '9', '8.5', '39',
#        '37', 'us 9.5/uk 8.0', 'us 9.0/uk 7.5', 'us 8.5/uk 7.0', '38.5',
#        '39.5', '42', '36', '40.5', '10.5', 'us 7.5/uk 6.0',
#        'us 6.5/uk 5.0', 's', 'us 10.0/uk 8.5', 'us 8.0/uk 6.5',
#        'us 10.5/uk 9.0', '40', '41', '11 med', '7 med', '9 wide',
#        '7.5 wide', '9.5 med', '41.5', 'us 11.0/uk 9.5', 'us 6.0/uk 4.5',
#        'us 7.0/uk 5.5', '40 wide', '6 med', '9 med', '8.5 med', '6.5 med',
#        '8 med', '10 med', '5', '36 wide', '38 wide', '41 wide', '7.5 med',
#        '5 med', '8 wide', '6 wide', '7 wide', '11 wide', '8.5 wide',
#        '9.5 wide', '12', '12 med', '5.5 med', '10.5 med', '10 wide',
#        '6.5 wide', '5.5', '35', '12 wide', '10.5 wide', '38',
#        'mens 5.5/womens 7.0', '11.5', '11.5 wide', '5 wide', '5.5 wide',
#        'mens 6.0/womens 7.5', 'mens 7.5/womens 9.0',
#        'mens 8.5/womens 10.0', 'mens 7.0/womens 8.5',
#        'mens 4.5/womens 6.0', 'medium', '4', 'small', 'large'],
#       dtype=object)

# %%
# address the incosistency in data

import re

#keep us size only

def extract_us_size(size):
    match_us = re.match(r'^us\s+(\d+(?:\.\d+)?)', size)
    if match_us:
        return match_us.group(1)
    return size

#keep womens size only

def extract_womens_size(size):
    match_womens = re.search(r'womens\s+(\d+(?:\.\d+)?)', size)
    if match_womens:
        return match_womens.group(1)
    return size

#keep size before med/wide

def extract_number_before_med_or_wide(size):
    match_med_or_wide = re.search(r'(\d+(?:\.\d+)?)\s+(?:med|wide)', size)
    if match_med_or_wide:
        return match_med_or_wide.group(1)
    return size

#replace s/small/medium/large with a number

def replace_values(value):
    replacements = {
        's': '5',
        'small': '5',
        'medium': '6',
        'large': '7'
    }
    return replacements.get(value, value)

# Apply the functions to the 'prices.size' column
df['prices.size']= df['prices.size'].apply(extract_us_size)
df['prices.size'] =df['prices.size'].apply(extract_womens_size)
df['prices.size']= df['prices.size'].apply(extract_number_before_med_or_wide)
df['prices.size'] = df['prices.size'].apply(replace_values)

print(df['prices.size'].unique())
# Out:
# ['7.5' '7' '9.5' '10' '6.5' '11' '6' '8' '9' '8.5' '39' '37' '9.0' '38.5'
#  '39.5' '42' '36' '40.5' '10.5' '5' '10.0' '8.0' '40' '41' '41.5' '11.0'
#  '6.0' '7.0' '38' '12' '5.5' '35' '11.5' '4']

# %%
# change all values to numeric

df['prices.size'] = pd.to_numeric(df['prices.size'], errors='coerce')

print(df['prices.size'].unique())

print(df['prices.size'].max())
# Out:
# [ 7.5  7.   9.5 10.   6.5 11.   6.   8.   9.   8.5 39.  37.  38.5 39.5
#  42.  36.  40.5 10.5  5.  40.  41.  41.5 38.  12.   5.5 35.  11.5  4. ]
# 42.0

# %%
import pandas as pd

import numpy as np

n=df['prices.size']

# Conversion table: EU sizes mapped to corresponding US sizes
to_us_sizes = {
    '34': 4,
    '34.5': 4.5,
    '35': 5,
    '35.5': 5.5,
    '36': 6,
    '36.5': 6,
    '37': 6.5,
    '37.5': 7,
    '38': 7.5,
    '38.5': 7.5,
    '39': 8,
    '39.5': 8.5,
    '40': 9,
    '40.5': 9.5,
    '41': 9.5,
    '41.5': 10,
    '42': 10.5
}

def convert_to_us(n):
    if n < 34:
        return n
    else:
        keys = sorted(to_us_sizes.keys(), key=float, reverse=True)

        for key in keys:
            if float(key) <= n:
                return to_us_sizes[key]

        return n  
    
df['prices.size'] = df['prices.size'].apply(convert_to_us)

print(df['prices.size'].unique())
# Out:
# [ 7.5  7.   9.5 10.   6.5 11.   6.   8.   9.   8.5 10.5  5.  12.   5.5
#  11.5  4. ]

# %%
sizes = df['prices.size'].value_counts()

# %%
fig, ax = plt.subplots(figsize=(12,12))

sns.barplot(x=sizes.index,y= sizes.values, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#https://www.viakix.com/blogs/news/average-womens-shoe-size

# %%
sns.lineplot(data=df, x="prices.size", y="prices.amountMax")
# Out:
# <AxesSubplot:xlabel='prices.size', ylabel='prices.amountMax'>

# %%
df['prices.merchant'] = df['prices.merchant'].str.lower()
df["avgprice"] = (df["prices.amountMax"] + df["prices.amountMin"])/2
df["discount"] = (df["prices.amountMin"] - df["prices.amountMax"])/df["prices.amountMax"]

# %%
df.brand = df.brand.str.lower()

# %%
df.brand.value_counts()
# Out:
# journee collection                2182
# lifestride                        1593
# a2 by aerosoles                    670
# easy street                        585
# style charles by charles david     478
#                                   ...
# ellie shoes                          1
# nyla                                 1
# kaanas                               1
# the north face                       1
# olivia miller                        1
# Name: brand, Length: 116, dtype: int64

# %%
df[df.brand == "easy street"]
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 9182  AVpfSv6IilAPnD_xY_mc  2017-01-09T19:44:38Z  2018-01-28T14:56:23Z   NaN
# 9176  AVpfSv6IilAPnD_xY_mc  2017-01-09T19:44:38Z  2018-01-28T14:56:23Z   NaN
# 9177  AVpfSv6IilAPnD_xY_mc  2017-01-09T19:44:38Z  2018-01-28T14:56:23Z   NaN
# 9178  AVpfSv6IilAPnD_xY_mc  2017-01-09T19:44:38Z  2018-01-28T14:56:23Z   NaN
# 9179  AVpfSv6IilAPnD_xY_mc  2017-01-09T19:44:38Z  2018-01-28T14:56:23Z   NaN
# ...                    ...                   ...                   ...   ...
# 8315  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8314  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8313  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8312  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8311  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
#
#             brand                                         categories  \
# 9182  easy street  Womens,Shoes,Athletic Shoes,Sneakers,Easy Stre...
# 9176  easy street  Womens,Shoes,Athletic Shoes,Sneakers,Easy Stre...
# 9177  easy street  Womens,Shoes,Athletic Shoes,Sneakers,Easy Stre...
# 9178  easy street  Womens,Shoes,Athletic Shoes,Sneakers,Easy Stre...
# 9179  easy street  Womens,Shoes,Athletic Shoes,Sneakers,Easy Stre...
# ...           ...                                                ...
# 8315  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8314  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8313  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8312  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8311  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
#
#      primaryCategories                                             colors  \
# 9182             Shoes  Black Leather,Fabric,Brown Leather,Navy Leathe...
# 9176             Shoes  Black Leather,Fabric,Brown Leather,Navy Leathe...
# 9177             Shoes  Black Leather,Fabric,Brown Leather,Navy Leathe...
# 9178             Shoes  Black Leather,Fabric,Brown Leather,Navy Leathe...
# 9179             Shoes  Black Leather,Fabric,Brown Leather,Navy Leathe...
# ...                ...                                                ...
# 8315             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8314             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8313             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8312             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8311             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
#
#      dimension           ean  ... weight  color women sandal   heel   high  \
# 9182       NaN  8.898850e+11  ...    NaN  black  True  False  False  False
# 9176       NaN  8.898850e+11  ...    NaN  brown  True  False  False  False
# 9177       NaN  8.898850e+11  ...    NaN  brown  True  False  False  False
# 9178       NaN  8.898850e+11  ...    NaN  brown  True  False  False  False
# 9179       NaN  8.898850e+11  ...    NaN   wine  True  False  False  False
# ...        ...           ...  ...    ...    ...   ...    ...    ...    ...
# 8315       NaN  8.860660e+11  ...    NaN    tan  True  False  False  False
# 8314       NaN  8.860660e+11  ...    NaN   navy  True  False  False  False
# 8313       NaN  8.860660e+11  ...    NaN  black  True  False  False  False
# 8312       NaN  8.860660e+11  ...    NaN  black  True  False  False  False
# 8311       NaN  8.860660e+11  ...    NaN   navy  True  False  False  False
#
#       boots   shoe avgprice discount
# 9182  False   True    59.99      0.0
# 9176  False   True    59.99      0.0
# 9177  False   True    59.99      0.0
# 9178  False   True    59.99      0.0
# 9179  False   True    59.99      0.0
# ...     ...    ...      ...      ...
# 8315  False  False    49.99      0.0
# 8314  False  False    49.99      0.0
# 8313  False  False    49.99      0.0
# 8312  False  False    49.99      0.0
# 8311  False  False    49.99      0.0
#
# [585 rows x 43 columns]

# %%
sns.regplot(data=df[df.brand == "easy street"], x="prices.size",y="avgprice")
# Out:
# <AxesSubplot:xlabel='prices.size', ylabel='avgprice'>

# %%
df.brand.value_counts().head(5).index
# Out:
# Index(['journee collection', 'lifestride', 'a2 by aerosoles', 'easy street',
#        'style charles by charles david'],
#       dtype='object')

# %%
es = df[df.brand.isin(df.brand.value_counts().head(10).index)]

# %%
es.head(1)
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 9810  AWKcE7YqYSSHbkXwy0XX  2018-04-06T17:33:30Z  2018-04-10T19:27:44Z   NaN
#
#      brand                                         categories  \
# 9810  nike  Women's Footwear,Women's Running Shoes,Women's...
#
#      primaryCategories                                             colors  \
# 9810             Shoes  Black/White-Anthracite,Glacier Blue/Metallic S...
#
#      dimension  ean  ...  weight  color women sandal   heel   high  boots  \
# 9810       NaN  NaN  ...  7.3 oz  black  True  False  False  False  False
#
#       shoe avgprice discount
# 9810  True   127.96     -0.4
#
# [1 rows x 43 columns]

# %%
es.groupby(["brand"])["avgprice"].mean()
# Out:
# brand
# a2 by aerosoles                   62.286866
# croft barrow                      50.172524
# dr. scholls                       66.297804
# easy street                       52.286368
# journee collection                61.831748
# lifestride                        52.113258
# nike                              67.904526
# skechers                          61.190610
# so                                42.964514
# style charles by charles david    74.618054
# Name: avgprice, dtype: float64

# %%
df['categories'] = df['categories'].str.split(',')

df['categories'] = df['categories'].apply(lambda x: [i.lower() for i in x])
df['categories'] = df['categories'].apply(lambda x: [i.replace('\'', '') for i in x])
df['categories'] = df['categories'].apply(lambda x: [i.replace('womens ', '') for i in x])

df['categories'] = df['categories'].apply(lambda x: 'Boots' if 'boots' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Heels and Pumps' if ('heels' in x) or ('pumps' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Sandals' if 'sandals' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Clogs and Mules' if ('clogs' in x) or ('mules' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Loafers' if 'loafers' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Flats' if 'flats' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Athletic Shoes' if ('athletic shoes' in x) or ('running shoes' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Other' if isinstance(x, list) else x)

# %%
df['categories'].value_counts().head(50)
# Out:
# Boots              2341
# Heels and Pumps    1936
# Athletic Shoes     1779
# Sandals            1721
# Flats              1165
# Clogs and Mules     476
# Loafers             320
# Other               262
# Name: categories, dtype: int64

# %%
gr = df.groupby("categories")["avgprice"]

# %%
gr.mean()
# Out:
# categories
# Athletic Shoes     70.853111
# Boots              66.131254
# Clogs and Mules    56.159139
# Flats              48.792408
# Heels and Pumps    55.591565
# Loafers            59.422781
# Other              77.677385
# Sandals            52.496150
# Name: avgprice, dtype: float64

# %%
gr.min()
# Out:
# categories
# Athletic Shoes     37.490
# Boots              31.935
# Clogs and Mules    32.490
# Flats              24.365
# Heels and Pumps    35.615
# Loafers            42.740
# Other               5.375
# Sandals            14.865
# Name: avgprice, dtype: float64

# %%
gr.max()
# Out:
# categories
# Athletic Shoes     179.95
# Boots              145.95
# Clogs and Mules     79.99
# Flats               89.99
# Heels and Pumps    130.00
# Loafers             90.00
# Other              359.95
# Sandals            125.00
# Name: avgprice, dtype: float64

# %%
sns.boxplot(df,x="avgprice",y="categories")
# Out:
# <AxesSubplot:xlabel='avgprice', ylabel='categories'>

# %%
df[df["avgprice"] > 250].T
# Out:
#                                                                   9701  \
# id                                                AWOC3uJ0YSSHbkXw0uzL
# dateAdded                                         2018-05-21T13:17:39Z
# dateUpdated                                       2018-06-22T12:17:10Z
# asins                                                              NaN
# brand                                                         red wing
# categories                                                       Other
# primaryCategories                                                Shoes
# colors                      Black Boundary,Mahogany Oro-Iginal Leather
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://images.evo.com/imgp/700/101834/466395/...
# keys                 redwingharrietbootswomens/eb1018341040,redwing...
# manufacturer                                                       NaN
# manufacturerNumber                                                 NaN
# name                                  Red Wing Harriet Boots - Women's
# prices.amountMax                                                359.95
# prices.amountMin                                                359.95
# prices.availability                                                NaN
# prices.color                                            Black Boundary
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                                   NaN
# prices.dateSeen              2018-05-17T16:00:00Z,2018-05-29T09:00:00Z
# prices.isSale                                                    False
# prices.merchant                                                    NaN
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                 This item qualifies for FREE SHIPPING!
# prices.size                                                        7.5
# prices.sourceURLs    https://www.evo.com/boots/red-wing-harriet-womens
# sizes                                       9.5,6,7,8,9,6.5,7.5,8.5,10
# sourceURLs           https://www.evo.com/boots/red-wing-harriet-womens
# upc                                                                NaN
# weight                                                             NaN
# color                                                            black
# women                                                             True
# sandal                                                           False
# heel                                                             False
# high                                                             False
# boots                                                             True
# shoe                                                             False
# avgprice                                                        359.95
# discount                                                           0.0
#
#                                                                   9702  \
# id                                                AWOC3uJ0YSSHbkXw0uzL
# dateAdded                                         2018-05-21T13:17:39Z
# dateUpdated                                       2018-06-22T12:17:10Z
# asins                                                              NaN
# brand                                                         red wing
# categories                                                       Other
# primaryCategories                                                Shoes
# colors                      Black Boundary,Mahogany Oro-Iginal Leather
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://images.evo.com/imgp/700/101834/466395/...
# keys                 redwingharrietbootswomens/eb1018341040,redwing...
# manufacturer                                                       NaN
# manufacturerNumber                                                 NaN
# name                                  Red Wing Harriet Boots - Women's
# prices.amountMax                                                359.95
# prices.amountMin                                                359.95
# prices.availability                                                NaN
# prices.color                               Mahogany Oro-Iginal Leather
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                                   NaN
# prices.dateSeen              2018-05-17T16:00:00Z,2018-05-29T09:00:00Z
# prices.isSale                                                    False
# prices.merchant                                                    NaN
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                 This item qualifies for FREE SHIPPING!
# prices.size                                                        7.0
# prices.sourceURLs    https://www.evo.com/boots/red-wing-harriet-womens
# sizes                                       9.5,6,7,8,9,6.5,7.5,8.5,10
# sourceURLs           https://www.evo.com/boots/red-wing-harriet-womens
# upc                                                                NaN
# weight                                                             NaN
# color                                      mahogany oro-iginal leather
# women                                                             True
# sandal                                                           False
# heel                                                             False
# high                                                             False
# boots                                                             True
# shoe                                                             False
# avgprice                                                        359.95
# discount                                                           0.0
#
#                                                                   9703  \
# id                                                AWOC3uJ0YSSHbkXw0uzL
# dateAdded                                         2018-05-21T13:17:39Z
# dateUpdated                                       2018-06-22T12:17:10Z
# asins                                                              NaN
# brand                                                         red wing
# categories                                                       Other
# primaryCategories                                                Shoes
# colors                      Black Boundary,Mahogany Oro-Iginal Leather
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://images.evo.com/imgp/700/101834/466395/...
# keys                 redwingharrietbootswomens/eb1018341040,redwing...
# manufacturer                                                       NaN
# manufacturerNumber                                                 NaN
# name                                  Red Wing Harriet Boots - Women's
# prices.amountMax                                                359.95
# prices.amountMin                                                359.95
# prices.availability                                                NaN
# prices.color                                            Black Boundary
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                                   NaN
# prices.dateSeen              2018-05-17T16:00:00Z,2018-05-29T09:00:00Z
# prices.isSale                                                    False
# prices.merchant                                                    NaN
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                 This item qualifies for FREE SHIPPING!
# prices.size                                                        9.5
# prices.sourceURLs    https://www.evo.com/boots/red-wing-harriet-womens
# sizes                                       9.5,6,7,8,9,6.5,7.5,8.5,10
# sourceURLs           https://www.evo.com/boots/red-wing-harriet-womens
# upc                                                                NaN
# weight                                                             NaN
# color                                                            black
# women                                                             True
# sandal                                                           False
# heel                                                             False
# high                                                             False
# boots                                                             True
# shoe                                                             False
# avgprice                                                        359.95
# discount                                                           0.0
#
#                                                                   9704  \
# id                                                AWOC3uJ0YSSHbkXw0uzL
# dateAdded                                         2018-05-21T13:17:39Z
# dateUpdated                                       2018-06-22T12:17:10Z
# asins                                                              NaN
# brand                                                         red wing
# categories                                                       Other
# primaryCategories                                                Shoes
# colors                      Black Boundary,Mahogany Oro-Iginal Leather
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://images.evo.com/imgp/700/101834/466395/...
# keys                 redwingharrietbootswomens/eb1018341040,redwing...
# manufacturer                                                       NaN
# manufacturerNumber                                                 NaN
# name                                  Red Wing Harriet Boots - Women's
# prices.amountMax                                                359.95
# prices.amountMin                                                359.95
# prices.availability                                                NaN
# prices.color                                            Black Boundary
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                                   NaN
# prices.dateSeen              2018-05-17T16:00:00Z,2018-05-29T09:00:00Z
# prices.isSale                                                    False
# prices.merchant                                                    NaN
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                 This item qualifies for FREE SHIPPING!
# prices.size                                                       10.0
# prices.sourceURLs    https://www.evo.com/boots/red-wing-harriet-womens
# sizes                                       9.5,6,7,8,9,6.5,7.5,8.5,10
# sourceURLs           https://www.evo.com/boots/red-wing-harriet-womens
# upc                                                                NaN
# weight                                                             NaN
# color                                                            black
# women                                                             True
# sandal                                                           False
# heel                                                             False
# high                                                             False
# boots                                                             True
# shoe                                                             False
# avgprice                                                        359.95
# discount                                                           0.0
#
#                                                                   9717
# id                                                AWOC3cR9YSSHbkXw0uGE
# dateAdded                                         2018-05-21T13:17:40Z
# dateUpdated                                       2018-05-21T13:17:40Z
# asins                                                              NaN
# brand                                                         red wing
# categories                                                       Other
# primaryCategories                                                Shoes
# colors                                              Oro Legacy Leather
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://images.evo.com/imgp/700/127051/532693/...
# keys                 evo.com-127051,redwing6inchclassicmocbootswome...
# manufacturer                                                       NaN
# manufacturerNumber                                                 NaN
# name                       Red Wing 6-inch Classic Moc Boots - Women's
# prices.amountMax                                                289.95
# prices.amountMin                                                289.95
# prices.availability                                                NaN
# prices.color                                        Oro Legacy Leather
# prices.condition                                                   NaN
# prices.currency                                                    USD
# prices.dateAdded                                                   NaN
# prices.dateSeen                                   2018-05-17T16:00:00Z
# prices.isSale                                                    False
# prices.merchant                                                    NaN
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                 This item qualifies for FREE SHIPPING!
# prices.size                                                        6.5
# prices.sourceURLs    https://www.evo.com/boots/red-wing-6-inch-clas...
# sizes                                               6.5,8,8.5,9,9.5,10
# sourceURLs           https://www.evo.com/boots/red-wing-6-inch-clas...
# upc                                                                NaN
# weight                                                             NaN
# color                                               oro legacy leather
# women                                                             True
# sandal                                                           False
# heel                                                             False
# high                                                             False
# boots                                                             True
# shoe                                                             False
# avgprice                                                        289.95
# discount                                                           0.0
