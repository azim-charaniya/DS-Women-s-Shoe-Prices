# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

import re
import os
# %matplotlib inline

# %%
df = pd.read_csv("Datafiniti_Womens_Shoes.csv")

# %%
df = df[df["prices.amountMax"] < 250]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9995 non-null   object
#  1   dateAdded            9995 non-null   object
#  2   dateUpdated          9995 non-null   object
#  3   asins                3 non-null      object
#  4   brand                9995 non-null   object
#  5   categories           9995 non-null   object
#  6   primaryCategories    9995 non-null   object
#  7   colors               2626 non-null   object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            9995 non-null   object
#  11  keys                 9995 non-null   object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 9995 non-null   object
#  15  prices.amountMax     9995 non-null   float64
#  16  prices.amountMin     9995 non-null   float64
#  17  prices.availability  434 non-null    object
#  18  prices.color         9995 non-null   object
#  19  prices.condition     434 non-null    object
#  20  prices.currency      9995 non-null   object
#  21  prices.dateAdded     9223 non-null   object
#  22  prices.dateSeen      9995 non-null   object
#  23  prices.isSale        9995 non-null   bool
#  24  prices.merchant      435 non-null    object
#  25  prices.offer         121 non-null    object
#  26  prices.returnPolicy  0 non-null      float64
#  27  prices.shipping      407 non-null    object
#  28  prices.size          9995 non-null   object
#  29  prices.sourceURLs    9995 non-null   object
#  30  sizes                9995 non-null   object
#  31  sourceURLs           9995 non-null   object
#  32  upc                  9640 non-null   object
#  33  weight               299 non-null    object
# dtypes: bool(1), float64(4), object(29)
# memory usage: 2.6+ MB

# %%
df.head().T
# Out:
#                                                                      0  \
# id                                                AVpfEf_hLJeJML431ueH
# dateAdded                                         2015-05-04T12:13:08Z
# dateUpdated                                       2018-01-29T04:38:43Z
# asins                                                              NaN
# brand                                                      Naturalizer
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                                Shoes
# colors                                  Silver,Cream Watercolor Floral
# dimension                                                          NaN
# ean                                                                NaN
# imageURLs            https://i5.walmartimages.com/asr/861ca6cf-fa55...
# keys                 naturalizer/47147sc022,017136472311,womensnatu...
# manufacturer                                                       NaN
# manufacturerNumber                                          47147SC022
# name                 Naturalizer Danya Women N/S Open Toe Synthetic...
# prices.amountMax                                                 55.99
# prices.amountMin                                                 55.99
# prices.availability                                                NaN
# prices.color                                        UWomens  M Regular
# prices.condition                                                   NaN
# prices.currency                                                    USD
# prices.dateAdded                                  2017-03-28T11:40:25Z
# prices.dateSeen      2017-03-25T09:19:24.819Z,2017-03-25T09:19:19.600Z
# prices.isSale                                                    False
# prices.merchant                                          Overstock.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                    NaN
# prices.size                                                          S
# prices.sourceURLs    https://www.overstock.com/Clothing-Shoes/Women...
# sizes                6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# sourceURLs           https://www.walmart.com/ip/Naturalizer-Danya-W...
# upc                                                        17136472311
# weight                                                             NaN
#
#                                                                      1  \
# id                                                AVpi74XfLJeJML43qZAc
# dateAdded                                         2017-01-27T01:23:39Z
# dateUpdated                                       2018-01-03T05:21:54Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                                          NaN
# ean                                                      33977045743.0
# imageURLs            https://i5.walmartimages.com/asr/421de5d5-3a74...
# keys                 mukluks/00173650206,033977045743,muklukswomens...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017365020-6
# name                               MUK LUKS Womens Jane Suede Moccasin
# prices.amountMax                                                  47.0
# prices.amountMin                                                 35.25
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2018-01-03T05:21:54Z
# prices.dateSeen      2017-12-08T14:24:00.000Z,2017-11-01T02:52:00.000Z
# prices.isSale                                                     True
# prices.merchant                                            Walmart.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                               Standard
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# upc                                                        33977045743
# weight                                                             NaN
#
#                                                                      2  \
# id                                                AVpi74XfLJeJML43qZAc
# dateAdded                                         2017-01-27T01:23:39Z
# dateUpdated                                       2018-01-03T05:21:54Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                                          NaN
# ean                                                      33977045743.0
# imageURLs            https://i5.walmartimages.com/asr/421de5d5-3a74...
# keys                 mukluks/00173650206,033977045743,muklukswomens...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017365020-6
# name                               MUK LUKS Womens Jane Suede Moccasin
# prices.amountMax                                                 35.25
# prices.amountMin                                                 35.25
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2017-12-06T05:02:42Z
# prices.dateSeen      2017-11-10T15:11:00.000Z,2017-11-18T08:00:00.000Z
# prices.isSale                                                    False
# prices.merchant                                       Slippers Dot Com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                  Value
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# upc                                                        33977045743
# weight                                                             NaN
#
#                                                                      3  \
# id                                                AVpjXyCc1cnluZ0-V-Gj
# dateAdded                                         2017-01-27T01:25:56Z
# dateUpdated                                       2018-01-04T11:52:35Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                          Shoes,Shoes
# colors                                                           Black
# dimension                                     6.0 in x 6.0 in x 1.0 in
# ean                                                      33977045903.0
# imageURLs            https://i5.walmartimages.com/asr/950d38a5-0113...
# keys                 033977045903,muklukswomensdawnsuedescuffslippe...
# manufacturer                                                  Muk Luks
# manufacturerNumber                                        0017366001-6
# name                          MUK LUKS Womens Dawn Suede Scuff Slipper
# prices.amountMax                                                 24.75
# prices.amountMin                                                 24.75
# prices.availability                                           In Stock
# prices.color                                                     Black
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2018-01-04T11:52:35Z
# prices.dateSeen                               2017-12-07T16:37:00.000Z
# prices.isSale                                                    False
# prices.merchant                                       Slippers Dot Com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                                  Value
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# upc                                                        33977045903
# weight                                                             NaN
#
#                                                                      4
# id                                                AVphGKLPilAPnD_x1Nrm
# dateAdded                                         2017-01-27T01:25:56Z
# dateUpdated                                       2018-01-18T03:55:18Z
# asins                                                              NaN
# brand                                                         MUK LUKS
# categories           Clothing,Shoes,Women's Shoes,All Women's Shoes...
# primaryCategories                                                Shoes
# colors                                                            Grey
# dimension                                     6.0 in x 6.0 in x 1.0 in
# ean                                                      33977045958.0
# imageURLs            https://i5.walmartimages.com/asr/5e137bc3-c900...
# keys                 mukluks/00173660206,033977045958,0033977045958...
# manufacturer                                                       NaN
# manufacturerNumber                                        0017366020-6
# name                          MUK LUKS Womens Dawn Suede Scuff Slipper
# prices.amountMax                                                  33.0
# prices.amountMin                                                 30.39
# prices.availability                                           In Stock
# prices.color                                                      Grey
# prices.condition                                                   New
# prices.currency                                                    USD
# prices.dateAdded                                  2017-12-04T21:35:47Z
# prices.dateSeen                               2017-11-17T21:15:00.000Z
# prices.isSale                                                     True
# prices.merchant                                            Walmart.com
# prices.offer                                                       NaN
# prices.returnPolicy                                                NaN
# prices.shipping                                              Expedited
# prices.size                                                          6
# prices.sourceURLs    https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# sizes                                                       10,7,6,9,8
# sourceURLs           https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# upc                                                        33977045958
# weight                                                             NaN

# %%
df.colors.fillna(df["prices.color"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9995 non-null   object
#  1   dateAdded            9995 non-null   object
#  2   dateUpdated          9995 non-null   object
#  3   asins                3 non-null      object
#  4   brand                9995 non-null   object
#  5   categories           9995 non-null   object
#  6   primaryCategories    9995 non-null   object
#  7   colors               9995 non-null   object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            9995 non-null   object
#  11  keys                 9995 non-null   object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 9995 non-null   object
#  15  prices.amountMax     9995 non-null   float64
#  16  prices.amountMin     9995 non-null   float64
#  17  prices.availability  434 non-null    object
#  18  prices.color         9995 non-null   object
#  19  prices.condition     434 non-null    object
#  20  prices.currency      9995 non-null   object
#  21  prices.dateAdded     9223 non-null   object
#  22  prices.dateSeen      9995 non-null   object
#  23  prices.isSale        9995 non-null   bool
#  24  prices.merchant      435 non-null    object
#  25  prices.offer         121 non-null    object
#  26  prices.returnPolicy  0 non-null      float64
#  27  prices.shipping      407 non-null    object
#  28  prices.size          9995 non-null   object
#  29  prices.sourceURLs    9995 non-null   object
#  30  sizes                9995 non-null   object
#  31  sourceURLs           9995 non-null   object
#  32  upc                  9640 non-null   object
#  33  weight               299 non-null    object
# dtypes: bool(1), float64(4), object(29)
# memory usage: 2.6+ MB

# %%
#df["colors"] = df['colors'].str.split(',')
#df = df.explode('colors').reset_index(drop=True)

# %%
df["color"] = df["prices.color"].str.lower()

# %%
df[df['color'].str.contains("gold", na=False)]["color"].unique()
# Out:
# array(['black rose gold', 'black gold', 'rose gold', 'gold', 'rosegold',
#        'soft gold', 'gold snake', 'rose gold glitter', 'rose gold brown',
#        'washed gold', 'metal gold', 'black gold combo', 'gold metallic',
#        'brindle/inca gold'], dtype=object)

# %%
df.color.value_counts().head(50)
# Out:
# black           1962
# gray             737
# taupe            558
# navy             535
# brown            301
# nude             225
# white            221
# blue             177
# stone            168
# tan              167
# pewter           157
# red              145
# black white      126
# chestnut         109
# mushroom         104
# olive             96
# dark tan          95
# silver            89
# gold              76
# wine              72
# cognac            72
# black fabric      69
# pink              69
# natural           65
# slate             63
# black micro       63
# dark gray         61
# blush             61
# sand              55
# whiskey           53
# black patent      53
# dark brown        51
# stucco            49
# bone              49
# burgundy          49
# black gray        49
# white sand        47
# white black       47
# lux navy          43
# camel             41
# navy fabric       40
# black combo       39
# black snake       37
# dark red          35
# gray pink         34
# navy velvet       33
# charcoal          31
# denim             31
# chocolate         30
# gray black        30
# Name: color, dtype: int64

# %%
df.color.value_counts()
# Out:
# black                                  1962
# gray                                    737
# taupe                                   558
# navy                                    535
# brown                                   301
#                                        ...
# beige metallic                            1
# brown burnish                             1
# black patent stretch                      1
# fjord                                     1
# armory blue/armory navy-cirrus blue       1
# Name: color, Length: 541, dtype: int64

# %%
# Spell Check for Gray
df["color"].replace(df[df['color'].str.contains("grey",na=False)]["color"].unique(), "gray", inplace=True)

# %%
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)

# %%
df.color.value_counts().head(50)
# Out:
# black                  2826
# gray                   1070
# navy                    741
# taupe                   573
# white                   430
# brown                   332
# nude                    231
# blue                    221
# stone                   185
# tan                     174
# pewter                  166
# red                     164
# silver                  128
# chestnut                109
# pink                    109
# mushroom                104
# olive                    96
# dark tan                 95
# wine                     89
# cognac                   84
# gold                     83
# natural                  70
# blush                    68
# slate                    66
# dark gray                61
# stucco                   57
# sand                     55
# burgundy                 54
# whiskey                  53
# dark brown               51
# charcoal                 50
# bone                     49
# lux navy                 43
# camel                    41
# dark red                 35
# denim                    31
# chocolate                31
# raspberry                27
# chambray blue combo      27
# purple                   26
# army                     24
# dark navy                24
# inky navy                23
# bronze                   23
# soft gold                23
# rosegold                 22
# rose gold                21
# midnight                 21
# beige                    19
# green                    18
# Name: color, dtype: int64

# %%
for n in df.color.value_counts().head(12).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)
for n in df.color.value_counts().head(12).index:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black            2885
# gray             1179
# navy              850
# taupe             577
# white             451
# brown             414
# blue              322
# tan               279
# nude              231
# red               213
# stone             189
# pewter            166
# silver            128
# chestnut          109
# pink              109
# mushroom          104
# olive              96
# wine               89
# cognac             84
# gold               83
# natural            70
# blush              68
# slate              66
# stucco             57
# sand               55
# burgundy           54
# whiskey            53
# charcoal           50
# bone               49
# camel              41
# denim              31
# chocolate          31
# raspberry          27
# purple             26
# army               24
# bronze             23
# soft gold          23
# rosegold           22
# rose gold          21
# midnight           21
# beige              19
# green              18
# merlot velvet      17
# metallic           17
# turquoise          16
# snake              15
# ice                14
# plum               14
# coral              13
# mauve              13
# Name: color, dtype: int64

# %%
commonCenterColors = ["navy","pink","gold","green","silver","chocolate","velvet","pewter","purple","bronze","nude","bone","rose","wine"]

# %%
for n in commonCenterColors:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)

for n in commonCenterColors:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black        2885
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# slate          66
# rose           66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# chocolate      32
# denim          31
# velvet         31
# purple         30
# raspberry      27
# army           24
# bronze         23
# midnight       21
# beige          19
# metallic       17
# turquoise      16
# snake          15
# ice            14
# plum           14
# mauve          13
# coral          13
# tornado        12
# glitter        11
# Name: color, dtype: int64

# %%
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.startswith(n,na=False)]["color"].unique(), n, inplace=True)
for n in df.color.value_counts().head(50).index:
    df["color"].replace(df[df['color'].str.contains(n,na=False)]["color"].unique(), n, inplace=True)
df.color.value_counts().head(50)
# Out:
# black        2885
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# rose           66
# slate          66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# coral          32
# chocolate      32
# velvet         31
# denim          31
# purple         30
# beige          28
# raspberry      27
# metallic       24
# army           24
# bronze         23
# leopard        22
# midnight       21
# snake          20
# turquoise      16
# ice            16
# mauve          14
# plum           14
# tornado        12
# Name: color, dtype: int64

# %%
df.color.value_counts()
# Out:
# black                 2885
# gray                  1179
# navy                   850
# taupe                  577
# white                  451
#                       ...
# willow                   1
# shell                    1
# floral combo             1
# night maroon             1
# uwomens  m regular       1
# Name: color, Length: 133, dtype: int64

# %%
df.color.value_counts().head(50)
# Out:
# black        2885
# gray         1179
# navy          850
# taupe         577
# white         451
# brown         414
# blue          322
# tan           279
# nude          231
# red           213
# stone         189
# pewter        166
# silver        129
# pink          125
# gold          112
# chestnut      109
# mushroom      104
# olive          96
# wine           89
# cognac         84
# natural        70
# blush          68
# rose           66
# slate          66
# stucco         57
# sand           55
# burgundy       54
# whiskey        53
# charcoal       50
# bone           49
# camel          41
# green          37
# coral          32
# chocolate      32
# velvet         31
# denim          31
# purple         30
# beige          28
# raspberry      27
# metallic       24
# army           24
# bronze         23
# leopard        22
# midnight       21
# snake          20
# turquoise      16
# ice            16
# mauve          14
# plum           14
# tornado        12
# Name: color, dtype: int64

# %%
df.color.value_counts().tail(50)
# Out:
# magenta                         4
# tort                            4
# mocha suede                     3
# mocha                           3
# fiji                            3
# cream                           3
# lilac                           3
# dark berry                      3
# walnut                          3
# carbon aruba                    3
# triangle                        3
# indigo burst                    2
# bleach                          2
# brunette                        2
# wheat nubuck                    2
# basalt/tapa                     2
# fatigue                         2
# aqua                            2
# morning dove heritage canvas    2
# maroon                          2
# unc multi                       2
# almond                          2
# bordeaux                        2
# mint                            1
# orange                          1
# buckskin                        1
# birch                           1
# poseidon/vintage indigo         1
# koa/tapa                        1
# honey                           1
# habana oiled leather            1
# tobacco oiled leather           1
# uwomens  n narrow               1
# team colors                     1
# capri/poseidon                  1
# wood                            1
# ram team                        1
# multi unicorn                   1
# sunrise                         1
# fjord                           1
# dusted peach                    1
# stripe                          1
# animal                          1
# gunmetal                        1
# camouflage                      1
# willow                          1
# shell                           1
# floral combo                    1
# night maroon                    1
# uwomens  m regular              1
# Name: color, dtype: int64

# %%
df.color.value_counts()
# Out:
# black                 2885
# gray                  1179
# navy                   850
# taupe                  577
# white                  451
#                       ...
# willow                   1
# shell                    1
# floral combo             1
# night maroon             1
# uwomens  m regular       1
# Name: color, Length: 133, dtype: int64

# %%
def getValidColor(c):
    _map = {'taupe': "#b38b6d","brown":"#A52A2A","nude":"#f2d3bc", "white":"#fffdd0"}
    if c in _map.keys() :
        return _map[c]
    else:
        return c

# %%
import seaborn as sns

colors = df.color.value_counts().head(5).index
for n in colors:
    sns.histplot(df[(df.color == n)]["prices.amountMax"],bins=30,kde=False,common_bins=True,label=n, color=getValidColor(n))

plt.suptitle('Shoes Price Distribution for top 5 colors', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")

plt.legend()

# %%
colors =df.color.value_counts().head(10).index
for n in colors:
    sns.kdeplot(df[(df["prices.amountMax"] < 350) & (df.color == n)]["prices.amountMax"], legend=True,label=n, color=getValidColor(n))

plt.suptitle('Shoes Price Distribution for top 10 colors', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")
plt.legend()

plt.savefig("10_kde_plot.png")

# %%
data = df.color.value_counts().head(10)

sns.barplot(x=data.index, y=data.values, palette=[getValidColor(n) for n in data.index])
plt.xlabel("Colors ")
plt.ylabel("Frequency")

plt.savefig("10_color_frequency.png")

# %%
fig, ax = plt.subplots(figsize = (12, 8))

sns.histplot(x = df['prices.amountMax'], kde=True, bins=50)
plt.suptitle('Shoes Price Distribution', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")
plt.savefig("distrubtion.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12, 8))

sns.histplot(x = df[(df["prices.amountMax"] < 250)]["prices.amountMax"], kde=True, bins=50)
plt.suptitle('Shoes Price Distribution Price Less than 250', fontsize = 20)
plt.xlabel("Price Range")
plt.ylabel("Frequency")

plt.show()

# %%
fig, ax = plt.subplots(2,1,figsize = (12, 8))

sns.boxplot(x = df["prices.amountMax"], ax = ax[0])
sns.histplot(x = df["prices.amountMax"], ax = ax[1], bins=30)
plt.suptitle('Box Plot for Prices', fontsize = 20)
plt.xlabel("Price Range")

plt.show()

# %%
top_brands =df.groupby('brand')['name'].count().reset_index().sort_values('name',ascending=False).head(10).set_index('brand')
plt.subplots(figsize=(14,7))
ax = top_brands['name'].sort_values().plot.barh(width=0.9,color=sns.color_palette('CMRmap',12))
ax.set_xlabel("Total items", fontsize=18)
ax.set_ylabel("Brand", fontsize=18)
ax.set_title("Top 10 Brands",fontsize=18,color='black')
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+2, i.get_y()+.3,str(round(i.get_width())), fontsize=15,color='black')
plt.show()

# %%
df =df.sort_values('prices.amountMax',ascending=False)
costliest_products =df.groupby('color')['prices.amountMax'].first().reset_index().sort_values('prices.amountMax',ascending=False).head(10).set_index('color')
plt.subplots(figsize=(14,7))
ax = costliest_products['prices.amountMax'].sort_values().plot.barh(width=0.9,color=sns.color_palette('gnuplot2_r',10))
ax.set_xlabel("Cost", fontsize=18)
ax.set_ylabel("color", fontsize=18)
ax.set_title("Costliest products of top 10 color",fontsize=18,color='black')
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+2, i.get_y()+.3,str(round(i.get_width())), fontsize=15,color='black')
plt.savefig("costliest_producsts.png")
plt.show()

# %%
import seaborn as sns
import math

fig, ax = plt.subplots(3, 3,figsize=(12,12))



colors = df.color.value_counts().head(9).index
for idx, n in enumerate(colors):
    _ax = ax[math.floor(idx/3)][idx%3]
    sns.histplot(df[(df["prices.amountMax"] < 350) & (df.color == n)]["prices.amountMax"],bins=30,kde=True,common_bins=True,label=n, ax = _ax, color=getValidColor(n))
    _ax.set_xlabel("Price Range")
    _ax.set_ylabel("Frequency")
    _ax.legend()
    _ax.lines[0].set_color('crimson')
    

plt.suptitle('Shoes Price Distribution for top 9 colors', fontsize = 20)

plt.savefig("distribution_hist.png")
plt.legend()

# %%
import seaborn as sns
import math

fig, ax = plt.subplots(3, 3,figsize=(12,12))



colors = df.color.value_counts().head(9).index
for idx, n in enumerate(colors):
    _ax = ax[math.floor(idx/3)][idx%3]
    data = df[df.color=="black"]["brand"].value_counts().head(10)
    sns.barplot(x=data.values, y=data.index, ax = _ax, color=getValidColor(n),orient='h')
    _ax.set_xlabel("Price Range for "+n)
    #_ax.set_ylabel("Frequency")
    #_ax.legend()
    
plt.savefig("brand_color.png")
plt.suptitle('Brand Price Distribution for top 9 colors', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Brand Price Distribution for top 9 colors')

# %%
data = df[df.color=="black"]["brand"].value_counts().head(10)

# %%
df["name"].value_counts()
# Out:
# Nike Flex Experience 6 Women's Running Shoes            185
# LifeStride Lively Women's High Heels                    157
# Dr. Scholl's Madison Women's Sneakers                   144
# Simply Vera Vera Wang Women's All-Over Stretch Heels    121
# Dr. Scholl's Jorie Women's Ankle Boots                  109
#                                                        ...
# La Sportiva Akasha Trail Running Shoe - Women's           1
# LC Lauren Conrad Women's Cutout Ankle Boots               1
# Journee Collection Selena Women's Ankle Boots             1
# Brooks Mazama Trail Running Shoe - Women's                1
# Time and Tru Women's Basic Ballet Flat                    1
# Name: name, Length: 647, dtype: int64

# %%
from collections import Counter
common = Counter(" ".join(df["name"].str.lower()).split()).most_common(100)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: matplotlib in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/christieccheng/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
wordcloud = WordCloud(colormap="coolwarm_r", width=1600, height=800).generate(" ".join([n[0] for n in common]))

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordcloud.to_file("wordcloud.png")

# %%
df['prices.size'].isnull().sum()
# Out:
# 0

# %%
df['prices.size'].unique()
# Out:
# array(['9', '8.5', '7', '11', '6', '8', '6.5', '10', '39', '37', '9.5',
#        'US 9.5/UK 8.0', 'US 9.0/UK 7.5', 'US 8.5/UK 7.0', '38.5', '39.5',
#        '36', '40.5', '42', '10.5', 'US 6.5/UK 5.0', 'US 7.5/UK 6.0', 'S',
#        'US 10.5/UK 9.0', '7.5', 'US 10.0/UK 8.5', 'US 8.0/UK 6.5', '40',
#        '41', '9 WIDE', '7 MED', '11 MED', '9.5 MED', '7.5 WIDE', '41.5',
#        'US 11.0/UK 9.5', 'US 7.0/UK 5.5', 'US 6.0/UK 4.5', '40 WIDE',
#        '8.5 MED', '9 MED', '6 MED', '8 MED', '6.5 MED', '10 MED', '5',
#        '38 WIDE', '36 WIDE', '7.5 MED', '41 WIDE', '5 MED', '8 WIDE',
#        '6 WIDE', '7 WIDE', '11 WIDE', '8.5 WIDE', '9.5 WIDE', '12',
#        '12 MED', '10 WIDE', '6.5 WIDE', '5.5 MED', '10.5 MED', '5.5',
#        '35', '12 WIDE', '10.5 WIDE', '38', 'Mens 5.5/Womens 7.0',
#        '11.5 WIDE', '11.5', '5 WIDE', '5.5 WIDE', 'Mens 7.5/Womens 9.0',
#        'Mens 8.5/Womens 10.0', 'Mens 6.0/Womens 7.5',
#        'Mens 7.0/Womens 8.5', 'Mens 4.5/Womens 6.0', 'Medium', '4',
#        'SMALL', 'MEDIUM', 'LARGE'], dtype=object)

# %%
#check unique data 
df['prices.size'] = df['prices.size'].str.lower()
df['prices.size'].unique()
# Out:
# array(['9', '8.5', '7', '11', '6', '8', '6.5', '10', '39', '37', '9.5',
#        'us 9.5/uk 8.0', 'us 9.0/uk 7.5', 'us 8.5/uk 7.0', '38.5', '39.5',
#        '36', '40.5', '42', '10.5', 'us 6.5/uk 5.0', 'us 7.5/uk 6.0', 's',
#        'us 10.5/uk 9.0', '7.5', 'us 10.0/uk 8.5', 'us 8.0/uk 6.5', '40',
#        '41', '9 wide', '7 med', '11 med', '9.5 med', '7.5 wide', '41.5',
#        'us 11.0/uk 9.5', 'us 7.0/uk 5.5', 'us 6.0/uk 4.5', '40 wide',
#        '8.5 med', '9 med', '6 med', '8 med', '6.5 med', '10 med', '5',
#        '38 wide', '36 wide', '7.5 med', '41 wide', '5 med', '8 wide',
#        '6 wide', '7 wide', '11 wide', '8.5 wide', '9.5 wide', '12',
#        '12 med', '10 wide', '6.5 wide', '5.5 med', '10.5 med', '5.5',
#        '35', '12 wide', '10.5 wide', '38', 'mens 5.5/womens 7.0',
#        '11.5 wide', '11.5', '5 wide', '5.5 wide', 'mens 7.5/womens 9.0',
#        'mens 8.5/womens 10.0', 'mens 6.0/womens 7.5',
#        'mens 7.0/womens 8.5', 'mens 4.5/womens 6.0', 'medium', '4',
#        'small', 'large'], dtype=object)

# %%
# address the incosistency in data

import re

#keep us size only

def extract_us_size(size):
    match_us = re.match(r'^us\s+(\d+(?:\.\d+)?)', size)
    if match_us:
        return match_us.group(1)
    return size

#keep womens size only

def extract_womens_size(size):
    match_womens = re.search(r'womens\s+(\d+(?:\.\d+)?)', size)
    if match_womens:
        return match_womens.group(1)
    return size

#keep size before med/wide

def extract_number_before_med_or_wide(size):
    match_med_or_wide = re.search(r'(\d+(?:\.\d+)?)\s+(?:med|wide)', size)
    if match_med_or_wide:
        return match_med_or_wide.group(1)
    return size

#replace s/small/medium/large with a number

def replace_values(value):
    replacements = {
        's': '5',
        'small': '5',
        'medium': '6',
        'large': '7'
    }
    return replacements.get(value, value)

# Apply the functions to the 'prices.size' column
df['prices.size']= df['prices.size'].apply(extract_us_size)
df['prices.size'] =df['prices.size'].apply(extract_womens_size)
df['prices.size']= df['prices.size'].apply(extract_number_before_med_or_wide)
df['prices.size'] = df['prices.size'].apply(replace_values)

print(df['prices.size'].unique())
# Out:
# ['9' '8.5' '7' '11' '6' '8' '6.5' '10' '39' '37' '9.5' '9.0' '38.5' '39.5'
#  '36' '40.5' '42' '10.5' '7.5' '5' '10.0' '8.0' '40' '41' '41.5' '11.0'
#  '7.0' '6.0' '38' '12' '5.5' '35' '11.5' '4']

# %%
# change all values to numeric

df['prices.size'] = pd.to_numeric(df['prices.size'], errors='coerce')

print(df['prices.size'].unique())

print(df['prices.size'].max())
# Out:
# [ 9.   8.5  7.  11.   6.   8.   6.5 10.  39.  37.   9.5 38.5 39.5 36.
#  40.5 42.  10.5  7.5  5.  40.  41.  41.5 38.  12.   5.5 35.  11.5  4. ]
# 42.0

# %%
import pandas as pd

import numpy as np

n=df['prices.size']

# Conversion table: EU sizes mapped to corresponding US sizes
to_us_sizes = {
    '34': 4,
    '34.5': 4.5,
    '35': 5,
    '35.5': 5.5,
    '36': 6,
    '36.5': 6,
    '37': 6.5,
    '37.5': 7,
    '38': 7.5,
    '38.5': 7.5,
    '39': 8,
    '39.5': 8.5,
    '40': 9,
    '40.5': 9.5,
    '41': 9.5,
    '41.5': 10,
    '42': 10.5
}

def convert_to_us(n):
    if n < 34:
        return n
    else:
        keys = sorted(to_us_sizes.keys(), key=float, reverse=True)

        for key in keys:
            if float(key) <= n:
                return to_us_sizes[key]

        return n  
    
df['prices.size'] = df['prices.size'].apply(convert_to_us)

print(df['prices.size'].unique())
# Out:
# [ 9.   8.5  7.  11.   6.   8.   6.5 10.   9.5  7.5 10.5  5.  12.   5.5
#  11.5  4. ]

# %%
sizes = df['prices.size'].value_counts()

# %%
fig, ax = plt.subplots(figsize=(12,12))

sns.barplot(x=sizes.index,y= sizes.values, ax=ax)
# Out:
# <Axes: >

# %%
#https://www.viakix.com/blogs/news/average-womens-shoe-size

# %%
sns.lineplot(data=df, x="prices.size", y="prices.amountMax")
# Out:
# <Axes: xlabel='prices.size', ylabel='prices.amountMax'>

# %%
df['prices.merchant'] = df['prices.merchant'].str.lower()
df["avgprice"] = (df["prices.amountMax"] + df["prices.amountMin"])/2
df["discount"] = ((df["prices.amountMin"] - df["prices.amountMax"])/df["prices.amountMax"])*-100

# %%
df.brand = df.brand.str.lower()

# %%
df.brand.value_counts()
# Out:
# journee collection                2182
# lifestride                        1593
# a2 by aerosoles                    670
# easy street                        585
# style charles by charles david     478
#                                   ...
# naturalizer                          1
# otzshoes                             1
# bogs                                 1
# nyla                                 1
# olivia miller                        1
# Name: brand, Length: 115, dtype: int64

# %%
df[df.brand == "easy street"]
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 9354  AV_MZV83uC1rwyj_hSSZ  2017-11-17T21:48:24Z  2018-02-01T07:33:00Z   NaN
# 9346  AV_MZV83uC1rwyj_hSSZ  2017-11-17T21:48:24Z  2018-02-01T07:33:00Z   NaN
# 9347  AV_MZV83uC1rwyj_hSSZ  2017-11-17T21:48:24Z  2018-02-01T07:33:00Z   NaN
# 9348  AV_MZV83uC1rwyj_hSSZ  2017-11-17T21:48:24Z  2018-02-01T07:33:00Z   NaN
# 9349  AV_MZV83uC1rwyj_hSSZ  2017-11-17T21:48:24Z  2018-02-01T07:33:00Z   NaN
# ...                    ...                   ...                   ...   ...
# 8313  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8312  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8311  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8310  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
# 8309  AVph-tAAilAPnD_x_Z9g  2017-01-17T19:08:45Z  2018-01-30T02:10:34Z   NaN
#
#             brand                                         categories  \
# 9354  easy street               Womens,Shoes,Pumps,Heels,Easy Street
# 9346  easy street               Womens,Shoes,Pumps,Heels,Easy Street
# 9347  easy street               Womens,Shoes,Pumps,Heels,Easy Street
# 9348  easy street               Womens,Shoes,Pumps,Heels,Easy Street
# 9349  easy street               Womens,Shoes,Pumps,Heels,Easy Street
# ...           ...                                                ...
# 8313  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8312  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8311  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8310  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
# 8309  easy street  Womens,Shoes,Clogs,Mules,Easy Street,Women's S...
#
#      primaryCategories                                             colors  \
# 9354             Shoes                                             Silver
# 9346             Shoes                                             Silver
# 9347             Shoes                                             Silver
# 9348             Shoes                                               Gold
# 9349             Shoes                                             Silver
# ...                ...                                                ...
# 8313             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8312             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8311             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8310             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
# 8309             Shoes  Navy,Brown Polyurethane,Black Tool Polyurethan...
#
#      dimension           ean  ... prices.shipping prices.size  \
# 9354       NaN           NaN  ...             NaN        12.0
# 9346       NaN           NaN  ...             NaN         7.5
# 9347       NaN           NaN  ...             NaN         9.0
# 9348       NaN           NaN  ...             NaN         9.5
# 9349       NaN           NaN  ...             NaN         9.0
# ...        ...           ...  ...             ...         ...
# 8313       NaN  8.860000e+11  ...             NaN         6.5
# 8312       NaN  8.860000e+11  ...             NaN         7.0
# 8311       NaN  8.860000e+11  ...             NaN         5.0
# 8310       NaN  8.860000e+11  ...             NaN         8.0
# 8309       NaN  8.860000e+11  ...             NaN         7.0
#
#                                       prices.sourceURLs  \
# 9354  https://www.kohls.com/product/prd-2792264/easy...
# 9346  https://www.kohls.com/product/prd-2792264/easy...
# 9347  https://www.kohls.com/product/prd-2792264/easy...
# 9348  https://www.kohls.com/product/prd-2792264/easy...
# 9349  https://www.kohls.com/product/prd-2792264/easy...
# ...                                                 ...
# 8313  https://www.kohls.com/product/prd-2594065/easy...
# 8312  https://www.kohls.com/product/prd-2594065/easy...
# 8311  https://www.kohls.com/product/prd-2594065/easy...
# 8310  https://www.kohls.com/product/prd-2594065/easy...
# 8309  https://www.kohls.com/product/prd-2594065/easy...
#
#                                                   sizes  \
# 9354  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 9346  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 9347  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 9348  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 9349  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# ...                                                 ...
# 8313  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 8312  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 8311  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 8310  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
# 8309  5 MED,5.5 MED,6 MED,6.5 MED,7 MED,7.5 MED,8 ME...
#
#                                              sourceURLs  \
# 9354  https://www.kohls.com/product/prd-2792264/easy...
# 9346  https://www.kohls.com/product/prd-2792264/easy...
# 9347  https://www.kohls.com/product/prd-2792264/easy...
# 9348  https://www.kohls.com/product/prd-2792264/easy...
# 9349  https://www.kohls.com/product/prd-2792264/easy...
# ...                                                 ...
# 8313  https://www.kohls.com/product/prd-2594065/easy...
# 8312  https://www.kohls.com/product/prd-2594065/easy...
# 8311  https://www.kohls.com/product/prd-2594065/easy...
# 8310  https://www.kohls.com/product/prd-2594065/easy...
# 8309  https://www.kohls.com/product/prd-2594065/easy...
#
#                                                     upc  weight   color  \
# 9354  889885219949,889885219499,889885219956,8898852...     NaN  silver
# 9346  889885219949,889885219499,889885219956,8898852...     NaN  silver
# 9347  889885219949,889885219499,889885219956,8898852...     NaN  silver
# 9348  889885219949,889885219499,889885219956,8898852...     NaN    gold
# 9349  889885219949,889885219499,889885219956,8898852...     NaN  silver
# ...                                                 ...     ...     ...
# 8313  886065942956,886065942055,886065942512,8860659...     NaN   black
# 8312  886065942956,886065942055,886065942512,8860659...     NaN   black
# 8311  886065942956,886065942055,886065942512,8860659...     NaN    navy
# 8310  886065942956,886065942055,886065942512,8860659...     NaN    navy
# 8309  886065942956,886065942055,886065942512,8860659...     NaN     tan
#
#      avgprice   discount
# 9354   50.615  31.255209
# 9346   51.240  29.171529
# 9347   59.990  -0.000000
# 9348   51.240  29.171529
# 9349   59.990  -0.000000
# ...       ...        ...
# 8313   49.990  -0.000000
# 8312   49.990  -0.000000
# 8311   49.990  -0.000000
# 8310   49.990  -0.000000
# 8309   49.990  -0.000000
#
# [585 rows x 37 columns]

# %%
sns.regplot(data=df[df.brand == "easy street"], x="prices.size",y="avgprice")
# Out:
# <Axes: xlabel='prices.size', ylabel='avgprice'>

# %%
df.brand.value_counts().head(5).index
# Out:
# Index(['journee collection', 'lifestride', 'a2 by aerosoles', 'easy street',
#        'style charles by charles david'],
#       dtype='object')

# %%
es = df[df.brand.isin(df.brand.value_counts().head(10).index)]

# %%
es.head(1)
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 9810  AWKcE7YqYSSHbkXwy0XX  2018-04-06T17:33:30Z  2018-04-10T19:27:44Z   NaN
#
#      brand                                         categories  \
# 9810  nike  Women's Footwear,Women's Running Shoes,Women's...
#
#      primaryCategories                                             colors  \
# 9810             Shoes  Black/White-Anthracite,Glacier Blue/Metallic S...
#
#      dimension  ean  ...                         prices.shipping prices.size  \
# 9810       NaN  NaN  ...  Free 2-Day shipping on orders over $50        10.0
#
#                                       prices.sourceURLs  \
# 9810  https://www.backcountry.com/nike-lunarepic-low...
#
#                                       sizes  \
# 9810  6.0,7.0,7.5,8.0,8.5,9.0,9.5,10.0,11.0
#
#                                              sourceURLs  upc  weight  color  \
# 9810  https://www.backcountry.com/nike-lunarepic-low...  NaN  7.3 oz  black
#
#      avgprice discount
# 9810   127.96     40.0
#
# [1 rows x 37 columns]

# %%
es.groupby(["brand"])["avgprice"].mean()
# Out:
# brand
# a2 by aerosoles                   62.286866
# croft barrow                      50.172524
# dr. scholls                       66.297804
# easy street                       52.286368
# journee collection                61.831748
# lifestride                        52.113258
# nike                              67.904526
# skechers                          61.190610
# so                                42.964514
# style charles by charles david    74.618054
# Name: avgprice, dtype: float64

# %%
df['categories'] = df['categories'].str.split(',')

df['categories'] = df['categories'].apply(lambda x: [i.lower() for i in x])
df['categories'] = df['categories'].apply(lambda x: [i.replace('\'', '') for i in x])
df['categories'] = df['categories'].apply(lambda x: [i.replace('womens ', '') for i in x])

df['categories'] = df['categories'].apply(lambda x: 'Dress Shoes' if 'red' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Boots' if 'boots' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Heels and Pumps' if ('heels' in x) or ('pumps' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Sandals' if 'sandals' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Clogs and Mules' if ('clogs' in x) or ('mules' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Loafers' if 'loafers' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Flats' if 'flats' in x else x)
df['categories'] = df['categories'].apply(lambda x: 'Athletic Shoes' if ('athletic shoes' in x) or ('running shoes' in x) else x)
df['categories'] = df['categories'].apply(lambda x: 'Other' if isinstance(x, list) else x)

# %%
df['categories'].value_counts().head(50)
# Out:
# Boots              2341
# Heels and Pumps    1936
# Athletic Shoes     1779
# Sandals            1721
# Flats              1165
# Clogs and Mules     476
# Loafers             320
# Other               257
# Name: categories, dtype: int64

# %%
gr = df.groupby("categories")["avgprice"]

# %%
gr.mean()
# Out:
# categories
# Athletic Shoes     70.853111
# Boots              66.131254
# Clogs and Mules    56.159139
# Flats              48.792408
# Heels and Pumps    55.591565
# Loafers            59.422781
# Other              72.458074
# Sandals            52.496150
# Name: avgprice, dtype: float64

# %%
gr.min()
# Out:
# categories
# Athletic Shoes     37.490
# Boots              31.935
# Clogs and Mules    32.490
# Flats              24.365
# Heels and Pumps    35.615
# Loafers            42.740
# Other               5.375
# Sandals            14.865
# Name: avgprice, dtype: float64

# %%
gr.max()
# Out:
# categories
# Athletic Shoes     179.95
# Boots              145.95
# Clogs and Mules     79.99
# Flats               89.99
# Heels and Pumps    130.00
# Loafers             90.00
# Other              178.00
# Sandals            125.00
# Name: avgprice, dtype: float64

# %%
ax = sns.boxplot(data=df,x="avgprice",y="categories")
ax.set(xlabel='Average Price', ylabel='Category', title='Distribution of Average Prices by Shoe Category')
plt.show()

# %%
ax = sns.barplot(data=df.groupby('categories')['id'].count().sort_values(ascending=False).reset_index(), x='id', y='categories', orient='h')
ax.set(xlabel='Count', ylabel='Category', title='Count by Shoe Type')
plt.show()

# %%
ax = sns.barplot(data=df.groupby('categories')['avgprice'].mean().sort_values(ascending=False).reset_index(), x='avgprice', y='categories', orient='h')
ax.set(xlabel='Average Price', ylabel='Category', title='Average Price by Shoe Type')
plt.show()

# %%
top_brands2 = df.groupby(['brand'], as_index=False)['id'].count().sort_values(by='id', ascending=False).head(9)['brand'].values

# %%
brands_and_categories = df.loc[df['brand'].isin(top_brands2)].groupby(['brand', 'categories'], as_index=False)['id'].count()

# %%
g = sns.FacetGrid(brands_and_categories, col="brand", col_wrap=3, hue='categories')
g.map_dataframe(sns.barplot, x="id", y='categories', order=brands_and_categories.categories.unique())
g.set_xlabels('Count')
g.set_ylabels('Category')
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Most Common Shoe Categories by Top Brands')
plt.show()

# %%
#BRAND

#Making copy of df with relevant columns only:
df1 = df[['brand', 'prices.amountMax', 'prices.amountMin', 'prices.merchant']]
df1.brand = df1.brand.str.lower()
df1["Avgprice"] = (df1["prices.amountMax"] + df1["prices.amountMin"])/2
df1.head()

#df1['prices.merchant'] = df1['prices.merchant'].str.lower()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/2908320243.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.brand = df1.brand.str.lower()
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/2908320243.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Avgprice"] = (df1["prices.amountMax"] + df1["prices.amountMin"])/2
#      brand  prices.amountMax  prices.amountMin  prices.merchant  Avgprice
# 9990  lowa            199.95             89.98  backcountry.com   144.965
# 9989  lowa            199.95             89.98  backcountry.com   144.965
# 9988  lowa            199.95            109.97  backcountry.com   154.960
# 9994  lowa            199.95             89.98  backcountry.com   144.965
# 9993  lowa            199.95             89.98  backcountry.com   144.965

# %%
# df1.brand.value_counts()

# %%
print(df1.brand.unique())
print(df1.brand.nunique())
# Out:
# ['lowa' 'asics' 'free people' 'frye' "arc'teryx" 'scarpa' 'la sportiva'
#  'on footwear' 'hoka one one' 'adidas' 'salomon' 'nike' 'new balance'
#  'splendid' 'mlb' 'under armour' 'altra' 'brooks' 'saucony' 'inov 8'
#  'softwalk' 'birkenstock' 'laredo' 'merrell' 'salewa' 'dansko' 'herstar'
#  'topo athletic' 'the north face' 'kaanas' 'rocky 4eursole' 'eastland'
#  'chaco' 'ugg' 'adidas outdoor' 'style charles by charles david' 'olukai'
#  'a2 by aerosoles' 'timberland' 'keen' 'seavees' 'lifestride'
#  'koolaburra by ugg' 'otzshoes' 'astral' 'dr. scholls' 'muk luks'
#  'journee collection' 'seychelles footwear' 'croft barrow' 'spring step'
#  'sperry top-sider' 'soludos' 'clarks' 'ryka' 'skechers' 'lugz'
#  'olivia miller' 'toms' 'vans' 'sonoma goods for life' 'apt. 9'
#  'kisses by 2 lips too' 'naturalsoul by naturalizer' '2 lips too' 'so'
#  'mammut' 'k-swiss' 'native shoes' 'puma' 'corkys'
#  'brinley co. collection' 'candies' 'lc lauren conrad' 'rampage'
#  'simply vera vera wang' 'madden nyc' 'betula by birkenstock' 'nyla'
#  'bogs' 'qupid' 'andrew geller' 'dolce by mojo moxy' 'jennifer lopez'
#  'easy street' 'fila' 'henry ferrera' 'naturalizer'
#  'soft style by hush puppies' 'keds' 'fergalicious' 'brinley co.' 'sugar'
#  'unionbay' 'forever young' 'reef' 'silver lilly' 'ib non-slip' 'seven7'
#  'ellie shoes' 'mo mo' 'daniel green' 'carrini' "dr. scholl's" 'sloggers'
#  'unique bargains' 'forever collectibles' 'riverberry' 'faded glory'
#  'genuine dickies' 'earth spirit' 'danskin now' 'victoria k.' 'soft ones'
#  'unbranded']
# 115

# %%
#Graph (1) - Top Brands in this Dataset
#calculate the number of shoes per brand, sort descending
brand_counts = df1.brand.value_counts().sort_values(ascending=False)
total = brand_counts.cumsum()
top_brands = brand_counts[total <= 7500]
print(top_brands)
#top_brands = brand_counts.head(50)
# Out:
# journee collection                2182
# lifestride                        1593
# a2 by aerosoles                    670
# easy street                        585
# style charles by charles david     478
# nike                               464
# so                                 422
# dr. scholls                        337
# skechers                           336
# croft barrow                       315
# Name: brand, dtype: int64

# %%
sns.barplot(x = top_brands.index, y = top_brands.values)
plt.xlabel('Brand')
plt.ylabel('Number of Shoes')
plt.title('10 Brands contain the Top 75% pairs of shoes (7500) in this dataset')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Average Price Per Brand

#making the binned by brand dataframe
df_bin1 = df1.groupby('brand')
avg_price = df_bin1['Avgprice'].mean().sort_values(ascending=False)
print(avg_price)
print(type(df_bin1))
print(type(avg_price))

#avg_price.head()
#Note: df_bin type = DataFrameGroupBy (?binned values cannot become a new DataFrame)
#Note: ave_priceMax = Series (column extracted from the temp binned DataFrame)
# Out:
# brand
# free people        178.000000
# on footwear        159.990000
# mlb                151.240000
# arc'teryx          150.166667
# la sportiva        149.437500
#                       ...
# genuine dickies     16.925000
# victoria k.         15.880000
# faded glory         13.381250
# soft ones           10.950000
# unbranded            6.803333
# Name: Avgprice, Length: 115, dtype: float64
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.series.Series'>

# %%
#BRAND Graph (2) Top 20 Brands with the highest average prices
sns.barplot(x = avg_price.head(10).index, y = avg_price.head(10).values, palette='husl')
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.title('Average Price for Each Brand for the top 10 most expensive brands')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Graph (3) Average price for top 10 brands
plt.figure(figsize=(6, 4))
sns.barplot(x = top_brands.index, y = avg_price.head(10).values)


plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.title('Average price of the top 10 brands in this dataset')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Graph (4) Average price for all brands
sns.lineplot(x = avg_price.index, y = avg_price.values)
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.title('Distribution of prices - All Brands')
plt.xticks([])
plt.show()

# %%
#Graph(5) - Distribution of price by most expensive and cheapest brands

#get list of brands with >100 data points
brands100 = df['brand'].value_counts()
brands100 = brands100[brands100 > 100].index.tolist()
#sort these brands by average price
df2 = avg_price[avg_price.index.isin(brands100)]

#get list of most and least expensive brands x5
list_h = df2.head(5).index.tolist()
list_t = df2.tail(5).index.tolist()
list_hnt = list_h + list_t
print(list_hnt)

#get df only containing data of the brands wanted
df3 = df1[df1['brand'].isin(list_hnt)]
# Out:
# ['asics', 'style charles by charles david', 'nike', 'dr. scholls', 'ryka', 'sonoma goods for life', 'croft barrow', 'candies', 'so', 'apt. 9']

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='brand', y='Avgprice', data=df3, order = list_hnt)

plt.xlabel('Brand')
plt.ylabel('Price')
plt.title('Distribution of prices - Top and bottom 5 most/least expensive brands')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Brands with the largest sales  (largest Max = Min)
#Create new attribute Maxmin_percent which shows % change
df1["Maxmin"] = df1["prices.amountMax"] - df1["prices.amountMin"]
df1["Maxmin_percent"] = df1['Maxmin'] / df1["prices.amountMax"] * 100
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/2683890406.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Maxmin"] = df1["prices.amountMax"] - df1["prices.amountMin"]
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/2683890406.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Maxmin_percent"] = df1['Maxmin'] / df1["prices.amountMax"] * 100

# %%
df_bin2 = df1.groupby("brand")
largestdiscount = df_bin2['Maxmin_percent'].mean().sort_values(ascending = False)
print(type(largestdiscount))
largestdiscount
# Out:
# <class 'pandas.core.series.Series'>
# brand
# silver lilly             57.514379
# splendid                 56.429311
# sonoma goods for life    55.117118
# lowa                     53.570535
# croft barrow             50.480078
#                            ...
# olukai                    0.000000
# on footwear               0.000000
# riverberry                0.000000
# rocky 4eursole            0.000000
# victoria k.               0.000000
# Name: Maxmin_percent, Length: 115, dtype: float64

# %%
#Graph (6): Top 20 Brands with the largest discounts
sns.barplot(x = largestdiscount.head(20).index, y = largestdiscount.head(20).values)
plt.xlabel('Brands')
plt.ylabel("Discount (%)")
plt.title("Brands offering the largest discounts")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#(7) Plot scatter plot using seaborn with y = maxmin_percent and x = avgprice, hue = binned brands by avg price

mean = df1.Avgprice.mean() #output = 60.03441870935468
#Bin again by average price (avg_price type = series)
avg_price = df1.groupby('brand')['Avgprice'].mean().sort_values(ascending=False)
#Map price category to avgprice acc to bands bin to sort brands into into high price (True) or low price (False)
df1['brand_type'] = df1['brand'].map(avg_price).apply(lambda x: 'expensive' if x > mean else 'cheap')

#to exclude shoes that have no difference between max and min price for sns plotting
df_sns = df1[df1['prices.amountMax'] != df1['prices.amountMin']]

df_sns.head()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/1785056573.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['brand_type'] = df1['brand'].map(avg_price).apply(lambda x: 'expensive' if x > mean else 'cheap')
#      brand  prices.amountMax  prices.amountMin  prices.merchant  Avgprice  \
# 9990  lowa            199.95             89.98  backcountry.com   144.965
# 9989  lowa            199.95             89.98  backcountry.com   144.965
# 9988  lowa            199.95            109.97  backcountry.com   154.960
# 9994  lowa            199.95             89.98  backcountry.com   144.965
# 9993  lowa            199.95             89.98  backcountry.com   144.965
#
#       Maxmin  Maxmin_percent brand_type
# 9990  109.97        54.99875  expensive
# 9989  109.97        54.99875  expensive
# 9988   89.98        45.00125  expensive
# 9994  109.97        54.99875  expensive
# 9993  109.97        54.99875  expensive

# %%
sns.scatterplot(x ="Avgprice", y ="Maxmin_percent", data=df_sns, hue ="brand_type", palette=['red', 'purple'])
plt.xlabel('Average Price of Shoes')
plt.ylabel('Size of Discount (%)')
# Out:
# Text(0, 0.5, 'Size of Discount (%)')

# %%
df[df["avgprice"] > 250].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [id, dateAdded, dateUpdated, asins, brand, categories, primaryCategories, colors, dimension, ean, imageURLs, keys, manufacturer, manufacturerNumber, name, prices.amountMax, prices.amountMin, prices.availability, prices.color, prices.condition, prices.currency, prices.dateAdded, prices.dateSeen, prices.isSale, prices.merchant, prices.offer, prices.returnPolicy, prices.shipping, prices.size, prices.sourceURLs, sizes, sourceURLs, upc, weight, color, avgprice, discount]

# %%
df.corr()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           ean  prices.amountMax  prices.amountMin  \
# ean                  1.000000         -0.001562          0.043595
# prices.amountMax    -0.001562          1.000000          0.666104
# prices.amountMin     0.043595          0.666104          1.000000
# prices.isSale       -0.329508          0.265893          0.096907
# prices.returnPolicy       NaN               NaN               NaN
# prices.size          0.137609          0.065776          0.069813
# avgprice             0.023576          0.904294          0.920768
# discount            -0.093361          0.043298         -0.688779
#
#                      prices.isSale  prices.returnPolicy  prices.size  \
# ean                      -0.329508                  NaN     0.137609
# prices.amountMax          0.265893                  NaN     0.065776
# prices.amountMin          0.096907                  NaN     0.069813
# prices.isSale             1.000000                  NaN    -0.029170
# prices.returnPolicy            NaN                  NaN          NaN
# prices.size              -0.029170                  NaN     1.000000
# avgprice                  0.194538                  NaN     0.074362
# discount                  0.053770                  NaN    -0.035716
#
#                      avgprice  discount
# ean                  0.023576 -0.093361
# prices.amountMax     0.904294  0.043298
# prices.amountMin     0.920768 -0.688779
# prices.isSale        0.194538  0.053770
# prices.returnPolicy       NaN       NaN
# prices.size          0.074362 -0.035716
# avgprice             1.000000 -0.371591
# discount            -0.371591  1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
leColor = LabelEncoder().fit(df.color)

# %%
df["leColor"] = leColor.transform(df.color)

# %%
df[df.color.isin(df.color.value_counts().head(5).index)].corr()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/1291580121.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df.color.isin(df.color.value_counts().head(5).index)].corr()
#                           ean  prices.amountMax  prices.amountMin  \
# ean                  1.000000          0.064326          0.043135
# prices.amountMax     0.064326          1.000000          0.655382
# prices.amountMin     0.043135          0.655382          1.000000
# prices.isSale       -0.318505          0.273908          0.089943
# prices.returnPolicy       NaN               NaN               NaN
# prices.size          0.054794          0.075882          0.073442
# avgprice             0.062945          0.898063          0.920804
# discount            -0.029241          0.047908         -0.698962
# leColor              0.118826         -0.061662         -0.039328
#
#                      prices.isSale  prices.returnPolicy  prices.size  \
# ean                      -0.318505                  NaN     0.054794
# prices.amountMax          0.273908                  NaN     0.075882
# prices.amountMin          0.089943                  NaN     0.073442
# prices.isSale             1.000000                  NaN    -0.018088
# prices.returnPolicy            NaN                  NaN          NaN
# prices.size              -0.018088                  NaN     1.000000
# avgprice                  0.193823                  NaN     0.081955
# discount                  0.066223                  NaN    -0.031655
# leColor                  -0.000953                  NaN     0.020033
#
#                      avgprice  discount   leColor
# ean                  0.062945 -0.029241  0.118826
# prices.amountMax     0.898063  0.047908 -0.061662
# prices.amountMin     0.920804 -0.698962 -0.039328
# prices.isSale        0.193823  0.066223 -0.000953
# prices.returnPolicy       NaN       NaN       NaN
# prices.size          0.081955 -0.031655  0.020033
# avgprice             1.000000 -0.382318 -0.054745
# discount            -0.382318  1.000000 -0.008704
# leColor             -0.054745 -0.008704  1.000000

# %%
leCategory = LabelEncoder().fit(df.categories)

# %%
df["dfCategory"] = leCategory.transform(df.categories)

# %%
df.corr()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           ean  prices.amountMax  prices.amountMin  \
# ean                  1.000000         -0.001562          0.043595
# prices.amountMax    -0.001562          1.000000          0.666104
# prices.amountMin     0.043595          0.666104          1.000000
# prices.isSale       -0.329508          0.265893          0.096907
# prices.returnPolicy       NaN               NaN               NaN
# prices.size          0.137609          0.065776          0.069813
# avgprice             0.023576          0.904294          0.920768
# discount            -0.093361          0.043298         -0.688779
# leColor              0.143099         -0.038295         -0.047988
# dfCategory           0.013621         -0.357686         -0.226669
#
#                      prices.isSale  prices.returnPolicy  prices.size  \
# ean                      -0.329508                  NaN     0.137609
# prices.amountMax          0.265893                  NaN     0.065776
# prices.amountMin          0.096907                  NaN     0.069813
# prices.isSale             1.000000                  NaN    -0.029170
# prices.returnPolicy            NaN                  NaN          NaN
# prices.size              -0.029170                  NaN     1.000000
# avgprice                  0.194538                  NaN     0.074362
# discount                  0.053770                  NaN    -0.035716
# leColor                  -0.018892                  NaN     0.003334
# dfCategory               -0.018967                  NaN    -0.040989
#
#                      avgprice  discount   leColor  dfCategory
# ean                  0.023576 -0.093361  0.143099    0.013621
# prices.amountMax     0.904294  0.043298 -0.038295   -0.357686
# prices.amountMin     0.920768 -0.688779 -0.047988   -0.226669
# prices.isSale        0.194538  0.053770 -0.018892   -0.018967
# prices.returnPolicy       NaN       NaN       NaN         NaN
# prices.size          0.074362 -0.035716  0.003334   -0.040989
# avgprice             1.000000 -0.371591 -0.047497   -0.316822
# discount            -0.371591  1.000000  0.023767   -0.027039
# leColor             -0.047497  0.023767  1.000000    0.060789
# dfCategory          -0.316822 -0.027039  0.060789    1.000000

# %%
#fig, ax = plt.subplots(figsize=(12,12))
gb = df.groupby('categories')["prices.amountMax"].agg(['min','mean','median','max'])

# %%
gb.index
# Out:
# Index(['Athletic Shoes', 'Boots', 'Clogs and Mules', 'Flats',
#        'Heels and Pumps', 'Loafers', 'Other', 'Sandals'],
#       dtype='object', name='categories')

# %%
gb.plot.bar()
# Out:
# <Axes: xlabel='categories'>

# %%
def _mapper(x):
    if(x < 50):
        return 1
    elif (x <100):
        return 2
    elif (x <150):
        return 3
    elif (x < 200):
        return 4
    else:
        return 5

# %%
df["bins"] = df["prices.amountMax"].apply(_mapper)

# %%
df.corr()
# Out:
# /var/folders/0p/j3xz875945x1yk5pyc1bvtdr0000gn/T/ipykernel_81698/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           ean  prices.amountMax  prices.amountMin  \
# ean                  1.000000         -0.001562          0.043595
# prices.amountMax    -0.001562          1.000000          0.666104
# prices.amountMin     0.043595          0.666104          1.000000
# prices.isSale       -0.329508          0.265893          0.096907
# prices.returnPolicy       NaN               NaN               NaN
# prices.size          0.137609          0.065776          0.069813
# avgprice             0.023576          0.904294          0.920768
# discount            -0.093361          0.043298         -0.688779
# leColor              0.143099         -0.038295         -0.047988
# dfCategory           0.013621         -0.357686         -0.226669
# bins                 0.052975          0.748514          0.512564
#
#                      prices.isSale  prices.returnPolicy  prices.size  \
# ean                      -0.329508                  NaN     0.137609
# prices.amountMax          0.265893                  NaN     0.065776
# prices.amountMin          0.096907                  NaN     0.069813
# prices.isSale             1.000000                  NaN    -0.029170
# prices.returnPolicy            NaN                  NaN          NaN
# prices.size              -0.029170                  NaN     1.000000
# avgprice                  0.194538                  NaN     0.074362
# discount                  0.053770                  NaN    -0.035716
# leColor                  -0.018892                  NaN     0.003334
# dfCategory               -0.018967                  NaN    -0.040989
# bins                      0.206003                  NaN     0.049923
#
#                      avgprice  discount   leColor  dfCategory      bins
# ean                  0.023576 -0.093361  0.143099    0.013621  0.052975
# prices.amountMax     0.904294  0.043298 -0.038295   -0.357686  0.748514
# prices.amountMin     0.920768 -0.688779 -0.047988   -0.226669  0.512564
# prices.isSale        0.194538  0.053770 -0.018892   -0.018967  0.206003
# prices.returnPolicy       NaN       NaN       NaN         NaN       NaN
# prices.size          0.074362 -0.035716  0.003334   -0.040989  0.049923
# avgprice             1.000000 -0.371591 -0.047497   -0.316822  0.684877
# discount            -0.371591  1.000000  0.023767   -0.027039  0.028352
# leColor             -0.047497  0.023767  1.000000    0.060789 -0.024935
# dfCategory          -0.316822 -0.027039  0.060789    1.000000 -0.243541
# bins                 0.684877  0.028352 -0.024935   -0.243541  1.000000

# %%
sns.scatterplot(df,x="avgprice",y="discount")
# Out:
# <Axes: xlabel='avgprice', ylabel='discount'>

# %%
dis = df[df.discount>0]

# %%
sns.regplot(dis,x="avgprice",y="discount")
# Out:
# <Axes: xlabel='avgprice', ylabel='discount'>

# %%
sns.regplot(dis,x="prices.amountMax",y="discount")
# Out:
# <Axes: xlabel='prices.amountMax', ylabel='discount'>

# %%
from fastai.tabular.all import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 from fastai.tabular.all import *
#
# ModuleNotFoundError: No module named 'fastai'

# %%
test_df = dis.sample(axis=0,frac=.05)

# %%
train_df =  dis.drop(test_df.index)

# %%
splits = RandomSplitter(seed=42)(train_df)

dls = TabularPandas(
    train_df, splits=splits,
    procs = [Categorify, FillMissing, Normalize],
    cat_names=["prices.size", "leColor"],
    cont_names=['discount','prices.amountMax'],
    y_names='dfCategory', y_block = CategoryBlock(),
).dataloaders(path=".")

learn = tabular_learner(dls, metrics=accuracy, layers=[64,32,16])

learn.fit(20, lr=0.03)

tst_dl = learn.dls.test_dl(test_df)

# %%
import torch

preds, _ = learn.get_preds(dl=tst_dl)

test_df['_preds'] = preds

def convertTensor(x):
    return leCategory.inverse_transform([torch.argmax(torch.tensor(x))])[0]

test_df['calculatedCategory'] = test_df['_preds'].apply(convertTensor)

# %%
test_df[["categories","calculatedCategory"]].head(50)

# %%
correct = sum(test_df["categories"] == test_df["calculatedCategory"])
correct

# %%
size = len(test_df["categories"])

# %%
correct/size
